# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk 
import string

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
print(train.info())
print(train.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31962 entries, 0 to 31961
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      31962 non-null  int64
#  1   label   31962 non-null  int64
#  2   tweet   31962 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 749.2+ KB
# None
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
print('positive_tweets count :',train[train.label==1].size)
print('negetive tweets count :',train[train.label==0].size)
print('positive_tweets example :\n',train[train.label==1].reset_index().tweet[3])
print('negetive tweets example :\n',train[train.label==0].reset_index().tweet[0])
# Out:
# positive_tweets count : 6726
# negetive tweets count : 89160
# positive_tweets example :
#  @user @user lumpy says i am a . prove it lumpy.
# negetive tweets example :
#   @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run

# %%
#hmmmmm in the above dataset we have a lot more negetive tweets than positive,we could work with this dataset by taking same number of negetive tweets instaed of taking all
#lets try nltk dataset

#The sample dataset from NLTK is separated into positive and negative tweets. 
#It contains 5000 positive tweets and 5000 negative tweets exactly. 
#The exact match between these classes is not a coincidence. 
#The intention is to have a balanced dataset. 
#That does not reflect the real distributions of positive and negative classes in live Twitter streams. 
#It is just because balanced datasets simplify the design of most computational methods that are required for sentiment analysis. 
#However, it is better to be aware that this balance of classes is artificial.




nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /home/shaffat/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %%
from nltk.corpus import twitter_samples
positve_tweets =  twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')

# %%
print('positive_tweets count : ',len(positve_tweets))
print('negative tweets count : ',len(negative_tweets))
print('positive example :\n',positve_tweets[0])
print('negative example :\n',negative_tweets[0])
# Out:
# positive_tweets count :  5000
# negative tweets count :  5000
# positive example :
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
# negative example :
#  hopeless for tmr :(

# %% [markdown]
# <p>Data preprocessing is one of the critical steps in any machine learning project. It includes cleaning and formatting the data before feeding into a machine learning algorithm. For NLP, the preprocessing steps are comprised of the following tasks:
# </p>
# <ul>
# <li>Tokenizing the string</li>
# <li>Lowercasing</li>
# <li>Removing stop words and punctuation</li>
# <li>Stemming</li>
# </ul>

# %%
import regex as re

# %%
def remove_hyperlink_retweet(twt):
    #remove old style retweet text 'RT'
    # remove old style retweet text "RT"
    twt = re.sub(r'^RT[\s]+', '', twt)

    # remove hyperlinks
    twt = re.sub(r'https?:\/\/.*[\r\n]*', '', twt)

    # remove hashtags
    # only removing the hash # sign from the word
    twt = re.sub(r'#', '', twt)
    
    return twt

# %%
print(positve_tweets[5])
print(remove_hyperlink_retweet(positve_tweets[5]))
# Out:
# @BhaktisBanter @PallaviRuhail This one is irresistible :)
# #FlipkartFashionFriday http://t.co/EbZ0L2VENM
# @BhaktisBanter @PallaviRuhail This one is irresistible :)
# FlipkartFashionFriday

# %%
from nltk.tokenize import TweetTokenizer
tokenizer = TweetTokenizer(preserve_case=False)
tweet_tokenize = tokenizer.tokenize(negative_tweets[0])
print(tweet_tokenize)
# Out:
# ['hopeless', 'for', 'tmr', ':(']

# %%
#remove stopwords and puncuations
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/shaffat/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
stopwords_eng  = stopwords.words('english')

# %%
print(stopwords_eng)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
def remove_stop_words(s):
    new_s = []
    for w in s:
        if w not in stopwords_eng:
            #check for puntuations but keep the emojis
            if len(w)==1:
                if w not in string.punctuation:
                    new_s.append(w)
            else:
                
                new_s.append(w)
    
    return new_s

# %%
print(negative_tweets[1])
print(remove_stop_words(tokenizer.tokenize(negative_tweets[1])))
# Out:
# Everything in the kids section of IKEA is so cute. Shame I'm nearly 19 in 2 months :(
# ['everything', 'kids', 'section', 'ikea', 'cute', 'shame', "i'm", 'nearly', '19', '2', 'months', ':(']

# %%
#stem the words
from nltk.stem import PorterStemmer

def stemming(s):
    new_s = []
    stemmer = PorterStemmer()
    for w in s:
        new_s.append(stemmer.stem(w))
    return new_s

# %%
#lets put everything together now
def process_the_tweets(sentences):
    tokenizer = TweetTokenizer(preserve_case=False)
    result  = []
    for sentence in sentences:
        clean = remove_hyperlink_retweet(sentence)
        tokens = tokenizer.tokenize(sentence)
        stop_words_removed = remove_stop_words(tokens)
        stemmed = stemming(stop_words_removed)
        result.append(stemmed)
    return result

# %%
process_the_tweets(negative_tweets)
# Out:
# [['hopeless', 'tmr', ':('],
#  ['everyth',
#   'kid',
#   'section',
#   'ikea',
#   'cute',
#   'shame',
#   "i'm",
#   'nearli',
#   '19',
#   '2',
#   'month',
#   ':('],
#  ['@hegelbon', 'heart', 'slide', 'wast', 'basket', ':('],
#  ['“', '@ketchburn', 'hate', 'japanes', 'call', 'bani', ':(', ':(', '”'],
#  ['dang', 'start', 'next', 'week', 'work', ':('],
#  ['oh', 'god', 'babi', 'face', ':(', 'https://t.co/9fcwgvaki0'],
#  ['@rileymcdonough', 'make', 'smile', ':('],
#  ['@f0ggstar',
#   '@stuartthul',
#   'work',
#   'neighbour',
#   'motor',
#   'ask',
#   'said',
#   'hate',
#   'updat',
#   'search',
#   ':(',
#   'http://t.co/xvmtuikwln'],
#  [':(', '@tahuodyy', 'sialan', ':(', 'https://t.co/hv1i0xcrl2'],
#  ['athabasca',
#   'glacier',
#   '#1948',
#   ':-(',
#   '#athabasca',
#   '#glacier',
#   '#jasper',
#   '#jaspernationalpark',
#   '#alberta',
#   '#explorealberta',
#   '…',
#   'http://t.co/dzzdqmf7cz'],
#  ['realli', 'good', 'g', 'idea', "i'm", 'never', 'go', 'meet', ':('],
#  ['@rampageinthebox', 'mare', 'ivan', ':('],
#  ['@sophiamascardo', 'happi', 'trip', 'keep', 'safe', 'see', 'soon', ':('],
#  ["i'm", 'tire', 'hahahah', ':('],
#  ['@grumpycockney', 'knee', 'replac', 'get', 'day', ':-(', 'ouch'],
#  ['relat',
#   'sweet',
#   'n',
#   'sour',
#   'kind',
#   'bi-polar',
#   'peopl',
#   'life',
#   '...',
#   'cuz',
#   'life',
#   '...',
#   'full',
#   '...',
#   ':('],
#  ['@aysegul_k', 'pleass', ':('],
#  ['@sexykalamo', 'im', 'sure', 'tho', ':('],
#  ['feel',
#   'stupid',
#   "can't",
#   'seem',
#   'grasp',
#   'basic',
#   'digit',
#   'paint',
#   'noth',
#   "i'v",
#   'research',
#   'help',
#   ':('],
#  ['good', 'lord', ':(', 'https://t.co/nc9lkyuuvo'],
#  ['feel',
#   'lone',
#   'someon',
#   'talk',
#   'guy',
#   'girl',
#   ':(',
#   '@theonlyrazzyt',
#   '@imarieuda',
#   '@eirozpegasu',
#   '@amysque',
#   '@udotv'],
#  ['assign', 'project', ':(', 'realli', '😩'],
#  ['want', 'play', 'video', 'game', 'watch', 'movi', 'someon', ':('],
#  ['choreograph', 'hard'],
#  ['@xo_raaaaayyy_xo',
#   'email',
#   'link',
#   'still',
#   'say',
#   'longer',
#   'avail',
#   ':(',
#   'http://t.co/iuiaioynnx'],
#  ['cri', 'bc', 'miss', 'mingm', 'much', ':-('],
#  ['sorri', ':(', 'https://t.co/q5tayjrq8k'],
#  ['@giannivnni', 'mom', 'far', 'away', ':('],
#  ["we'r", 'truli', 'sorri', '@chrisbrown', ':(', 'safe', 'flight'],
#  ['friend', ':('],
#  ['@bbygjrlmgc', 'oh', ':(', 'hate', 'happen', 'get', 'sad'],
#  ['oh',
#   'dog',
#   'pee',
#   '’',
#   '@kneewax',
#   'bag',
#   ':-(',
#   '’',
#   'take',
#   '#newwine15'],
#  ['@ym_dish98', 'doushit', ':('],
#  ['@charliescoco', '@reeceftcharlii', '@simoncowel', 'late', ':('],
#  ['suck',
#   'much',
#   'sick',
#   'plan',
#   'start',
#   'work',
#   'first',
#   'gundam',
#   'night',
#   'nope',
#   ':('],
#  ['2', 'dollar', ':(', '😭', '😭', '😭', 'http://t.co/oi0pygusdi'],
#  ['@martylog',
#   'listen',
#   'back',
#   'old',
#   '@davegorman',
#   'show',
#   'know',
#   "i'm",
#   'weird',
#   'got',
#   'u',
#   'leav',
#   'might',
#   'give',
#   'pale',
#   'imit',
#   ':-('],
#  ['went',
#   'sea',
#   'massiv',
#   'fuck',
#   'rash',
#   'bodi',
#   'pain',
#   'thing',
#   'ever',
#   'want',
#   'go',
#   'home',
#   ':('],
#  ['@dethronedlwt', 'hi', 'absent', ':('],
#  ['gran', 'tho', 'knew', 'care', 'tell', ':('],
#  ['@rowysoijp', 'cute', 'love', 'much', 'wish', 'would', 'sequel', ':('],
#  ['@imallyssagail',
#   'busi',
#   'sa',
#   'school',
#   ':(',
#   'next',
#   'time',
#   'love',
#   'yah',
#   'xx'],
#  ['ouucchhh', 'one', 'wisdom', 'teeth', 'come', ':('],
#  ['@stevenldn', 'frighten', 'case', 'realli', 'get', ':('],
#  ['pret',
#   ':(',
#   'wkwkw',
#   '@wlk_jhope',
#   'verfi',
#   '@wlk_hyemi91',
#   'activ',
#   'forget',
#   'follow',
#   'member',
#   'thank',
#   'join',
#   'goodby'],
#  ['´', 'got', 'chain', 'love', '´', '—', 'sentir-s', 'incompleta'],
#  ['okay', '..', '..', ':('],
#  ['@njhftbieb', 'go', 'wednesday', ':('],
#  ['@radicalj', 'marvel', 'thwart', ':-('],
#  ['@ceeels95',
#   'awh',
#   "what'",
#   'chanc',
#   '😩',
#   'u',
#   'zant',
#   'need',
#   'someth',
#   ':-(',
#   'x'],
#  ['@s0ulfl0wr', "when'", 'birthday', ':('],
#  ['@brittleyouth',
#   '@tom_j_allen',
#   '@andrewfairbairn',
#   '@batemanesqu',
#   '@hegelbon',
#   '@jameswheel',
#   'worst',
#   'part',
#   'still',
#   'feel',
#   'bad',
#   ':('],
#  ['audraesar', 'sushi', 'pic', 'tl', 'drive', 'craaaazzyy', ':('],
#  ['realli', 'want', ':(', 'http://t.co/36tsy81imi'],
#  ['pop', 'like', 'helium', 'balloon', '..', ':-('],
#  ['#climatechang',
#   '#cc',
#   "california'",
#   'power',
#   'influenti',
#   'air',
#   'pollut',
#   'watchdog',
#   'califor',
#   '...',
#   'http://t.co/ovu4p2qwfh',
#   '#uniteblu',
#   '#tcot',
#   ':-('],
#  ['@itsnotmirna',
#   'sad',
#   'elhaida',
#   'rob',
#   'juri',
#   ':(',
#   'came',
#   '10th',
#   'televot'],
#  ['#climatechang',
#   '#cc',
#   'idaho',
#   'restrict',
#   'fish',
#   'despit',
#   'region',
#   'drought-link',
#   'die-of',
#   '...',
#   'http://t.co/jjbodo6lyz',
#   '#uniteblu',
#   '#tcot',
#   ':-('],
#  ['#climatechang',
#   '#cc',
#   'abrupt',
#   'climat',
#   'chang',
#   'may',
#   'doom',
#   'mammoth',
#   'megafauna',
#   'sc',
#   '...',
#   'http://t.co/tavmcz37e7',
#   '#uniteblu',
#   '#tcot',
#   ':-('],
#  ['#climatechang',
#   '#cc',
#   "australia'",
#   'dirtiest',
#   'power',
#   'station',
#   'consid',
#   'clean',
#   'energi',
#   'biomass',
#   '...',
#   'http://t.co/yeqabq6tsl',
#   '#uniteblu',
#   '#tcot',
#   ':-('],
#  ['#climatechang',
#   '#cc',
#   "ain't",
#   'easi',
#   'green',
#   'golf',
#   'cours',
#   'california',
#   'ulti',
#   '...',
#   'http://t.co/la82rxzts2',
#   '#uniteblu',
#   '#tcot',
#   ':-('],
#  ['@mess0019', 'well', 'sure', 'work', 'day', 'mine', ':('],
#  ['@keikopotato', 'im', 'gonna', 'miss', 'u', 'sexi', 'prexi', ':('],
#  ['miss', 'kindergarten', 'kid', ':('],
#  ['hungri', ':-('],
#  ['cant', 'find', 'book', 'keep', 'sane', ':('],
#  ['liter', 'three', 'loung', 'event', ':-(', 'much', 'turn', "i'm", 'sad'],
#  ['@carliot23', 'miss', 'boss', ':('],
#  ['love', 'hozier', ':-('],
#  ['@izzytailford', "that'", 'true', 'want', 'soooooooner', ':('],
#  ['ahh', 'fam', '@meekmil', ':(', '#respectlost', 'http://t.co/nt25myngyd'],
#  ['@shokako1104', "i'm", 'sorri', ':(', 'hypercholesteloremia', 'ok'],
#  ['babi', 'still', 'look', 'tire', ':('],
#  ['someon', 'gift', 'calibraska', ':('],
#  ['@rico_shabbir',
#   'massiv',
#   'shame',
#   'would',
#   'actual',
#   'genuin',
#   'contend',
#   'happen',
#   ':('],
#  ['head', 'alway', 'hurt', 'stay', 'late', 'lmao', ':('],
#  ['@ernestlozoya', 'u', 'older', ':('],
#  ['back', ':('],
#  ['u', 'sound', 'upset', ':(', 'https://t.co/jzbfbkld8q'],
#  ['much', 'miss', ':-(', 'https://t.co/pn2hvgdnft'],
#  ['miss', 'infinit', ':-('],
#  ['@discoq', 'ao', 'want', 'stick', '8th', 'either', ':('],
#  ['@madrigalandreaa', 'much', 'seriou', 'yun', 'eh', ':('],
#  ['room', 'way', 'hot', ':-('],
#  ['still', 'havent', 'found', 'handsom', 'jack', 'draw', ':('],
#  ['@twcxmina', 'shit', ':('],
#  ['cut', 'encor', ':(', '#bad4thwin'],
#  ['wish', 'baymax', ':('],
#  ['sick', ':('],
#  ['@littlemix', 'french', 'mixer', 'miss', 'much', ':(', '💜'],
#  ['wft',
#   '..',
#   "can't",
#   'watch',
#   'awesom',
#   'replay',
#   ':-(',
#   'https://t.co/chzrqtelph'],
#  ['@viiiiiiiiev', 'happen', ':('],
#  ['parti', 'promot', ':('],
#  ['music', 'bank', 'encor', 'alway', 'short', ':('],
#  ['babi', 'boy', ':('],
#  ['@flipkartsupport',
#   'order',
#   'receiv',
#   'hub',
#   'nearest',
#   'look',
#   'like',
#   'deliv',
#   'today',
#   ':(',
#   '1/2'],
#  ['mum', 'play', 'music', 'loud', ':('],
#  ['final', 'parasyt', 'fuck', 'feel', 'alllllll', 'way', ':('],
#  ['wish', ':(', '#zayniscomingbackonjuly26'],
#  ['good', 'bye', 'parti', 'era', ':('],
#  ['@amedefu', '。', '。', '。', ':(', '´', 'ω', '」', '∠', '):'],
#  ['@concept_nathan',
#   'nathann',
#   '💕',
#   'never',
#   'got',
#   'chanc',
#   'take',
#   'pic',
#   ':(',
#   'got',
#   'hug',
#   'tho',
#   'pic',
#   'next',
#   'time',
#   'see',
#   '😊'],
#  ['girl', 'came', 'like', 'beauti', ':-(', 'want', 'dieididieieiei', 'cute'],
#  ['parti', 'goodby', 'stage', ':(', 'mean', 'hello', 'lion', 'heart', 'think'],
#  ['@msdanneh',
#   '@obey_ervin15',
#   'tell',
#   'screw',
#   "i'm",
#   'gonna',
#   'netflix',
#   'chill',
#   'u',
#   'di',
#   'ervin',
#   ':('],
#  ['@subharri', 'ohh', ':(', 'yeah', 'hope', 'come', 'back', 'soon'],
#  ['@madnitahir',
#   "i'v",
#   'accept',
#   'offer',
#   '..',
#   'im',
#   'desper',
#   'take',
#   'year',
#   ':('],
#  ['come', 'back', ':('],
#  ['snapchat',
#   'amargolonnard',
#   '#snapchat',
#   '#snapchat',
#   '#kikhorni',
#   '#snapm',
#   '#tagsforlik',
#   '#batalladelosgallo',
#   '#webcamsex',
#   ':(',
#   'http://t.co/3s9lhafrsu'],
#  ['ugh', 'cant', 'stream', 'tmr', 'duti', ':('],
#  ['@madrigalandreaa', "u'v", 'gone', 'far', ':('],
#  ['@uhhaileeni', 'alien', 'thing', ':('],
#  ['@ni_all_is_ba',
#   'aww',
#   'realli',
#   'wanna',
#   'get',
#   'hope',
#   'wish',
#   'would',
#   ':('],
#  ['@malikm0ney', 'sorka', ':('],
#  ['@fxnno_',
#   'knew',
#   'u',
#   'would',
#   'sad',
#   ':(',
#   'funer',
#   'gonna',
#   'text',
#   'u',
#   'phone'],
#  ['sunni', ':(', 'feel', 'bad', '...', 'http://t.co/17tca0uhkp'],
#  ['nonexist', 'wowza', ':('],
#  ['@izgzb', '@aishahyussofff', 'back', 'fah', 'mine', ':-('],
#  ['@dimpledjai', 'taylor', 'crop', ':('],
#  ['@nickjdrak', 'boo', 'count', ':-('],
#  ['new', 'guitar', ':('],
#  ['@pinkcloud_rp', 'get', 'jonghyun', 'hyung', ':(', 'pleas', 'predict', ':('],
#  ['hope', 'sj', 'nomin', 'soon', 'sj', 'vs', 'infinit', 'pl', ':('],
#  ['yeah', 'dude', 'keep', 'calm', 'brace', ':-(', 'https://t.co/znojt3v9gq'],
#  ['@mr_frml', 'sir', 'plu', '4', 'pleas', ':('],
#  ['look', 'shock', 'omgggg', ':(', 'yall', 'deserv', ':('],
#  ['whenev',
#   'would',
#   'spend',
#   'night',
#   'would',
#   'smoke',
#   'watch',
#   'movi',
#   'would',
#   'alway',
#   'end',
#   'fall',
#   'asleep',
#   ':('],
#  ['1', 'point', 'close', 'grand', 'final', ':(', 'whyyi'],
#  ['@muhammadsk', ':(', "that'", 'long', 'time'],
#  ['@evanquick',
#   'oh',
#   'must',
#   'annoy',
#   'evan',
#   ':(',
#   'text',
#   'give',
#   'option',
#   'opt'],
#  ["who'", 'giveaway', 'muster', 'good', ':(', 'merch'],
#  ['@wendyykid', 'ah', 'bad', ':('],
#  ['peopl', 'look', 'funni', "i'm", 'drink', 'savanna', 'straw', ':('],
#  ['good', 'bye', 'stage', ':('],
#  ['@ameliahartin', 'ignor', 'yester', 'afternoon', ':('],
#  ["can't", 'sleep', ':(', 'someon', 'talk'],
#  ['yeah', ':('],
#  ['@_birexu', 'ye', 'sadli', ':('],
#  ['@claireclaire05', ':('],
#  ['@the_stryp', 'when', 'album', 'come', ':('],
#  ['last', 'chocol', 'consum', ':('],
#  ['ugh', 'werk', 'morn', ':-('],
#  ['@deedee_50fli', 'foreal', ':(', 'wesen', 'uwes', 'mj', '😂', '😩'],
#  ['@crazynov',
#   'catch',
#   'onlin',
#   'long',
#   'enough',
#   'haha',
#   "he'",
#   'annoy',
#   ':('],
#  ['bosen', ':('],
#  ['die', 'egg', 'benni', ':('],
#  ['@michael5so', 'sometim', 'hate', ':('],
#  ['@mark23baracael', 'babi', 'followback', 'huhu', ':('],
#  ['@fkluca', 'one', 'cute', 'u', ':('],
#  ['@tinkkza',
#   'gonna',
#   'watch',
#   'shit',
#   'understand',
#   'badli',
#   'scare',
#   '>:(',
#   'https://t.co/ycguditqgx'],
#  ['miss', 'al', 'kati', 'zaz', 'ami', 'lot', ':('],
#  ['like', '@youtub', 'video', 'http://t.co/2jcbiswdw9', 'sub', 'plz', ':('],
#  ['@littlemix', '@sonymusicnl', 'u', 'make', 'diari', 'pleas', ':('],
#  ['@neikmat', 'sorri', ':('],
#  ['@twyodor',
#   '@gkjohn',
#   ':-(',
#   'read',
#   'rehash',
#   'websit',
#   'mushroom',
#   'good',
#   'piec',
#   'may',
#   'except',
#   'reach',
#   'one',
#   'anyway'],
#  ['@daddyksoo', 'ye', 'vicki', 'omg', ':-('],
#  ['@megsyfoxi',
#   'wtf',
#   'like',
#   'lip',
#   'still',
#   'virgin',
#   'omg',
#   'mom',
#   'get',
#   'life',
#   'your',
#   '45',
#   'hahah'],
#  ['@pastelwolfxx',
#   '@cha_nnnnn',
#   'ninasti',
#   'tsktsk',
#   'oppa',
#   'wont',
#   'like',
#   'u',
#   'call',
#   'dick',
#   'kawaii',
#   'manli',
#   '>:(',
#   'http://t.co/83cugt7qq3'],
#  ['lone', ':(', 'http://t.co/vm4n0n8bkw'],
#  ["can't", 'go', 'back', 'sleep', ':('],
#  ['wanna', 'go', 'xbox', 'netflix', 'alreadi', 'comfi', 'bed', ':('],
#  ['@baileymac02', 'miss', 'youu', ':('],
#  ['sigh', 'feel', 'bad', 'girl', ':('],
#  ['@oh_so_ehmte', 'lol', 'love', 'sweet', 'potato', 'fri', ':('],
#  ['@_birexu', 'guess', "y'all", 'ugli', 'asf', 'huh', ':('],
#  ['@dsitando',
#   'eish',
#   'ive',
#   'quit',
#   'know',
#   '...',
#   'lost',
#   'twitter',
#   'mojo',
#   'shame',
#   '...',
#   'n',
#   'dont',
#   'know',
#   'get',
#   'back',
#   ':(',
#   'mara',
#   'im',
#   'sure',
#   'help',
#   'neh'],
#  ['aww', "i'v", 'got', 'fever', ':(', '#bad4thwin', '<3'],
#  ['poor', 'bb', ':('],
#  ['@ursulawj',
#   '@owenwintermyp',
#   "i'm",
#   'abl',
#   'go',
#   ':(',
#   'associ',
#   'green',
#   'councillor',
#   'confer',
#   'weekend',
#   '...'],
#  ['skype',
#   'account',
#   'order',
#   'think',
#   'hack',
#   'contact',
#   "i'm",
#   'sorri',
#   ':(',
#   "i'm",
#   'creat',
#   'new',
#   'one',
#   'soon'],
#  ['@selenagomez', 'miss', 'tweet', 'spree', 'oh', ':('],
#  ['ye',
#   'na',
#   'sholong',
#   'reject',
#   'propos',
#   ':(',
#   '@elzzika',
#   'gee',
#   'u',
#   'fli',
#   'go',
#   'gidi',
#   '@gatlinho',
#   'way',
#   "i'm",
#   'pamper',
#   'lago',
#   'ehn',
#   '...'],
#  ['@isxb', 'guess', 'im', 'arrest', 'girlfriend', ':('],
#  ['@prophdog_',
#   '@attep',
#   'he',
#   'nice',
#   'person',
#   'idk',
#   'anybodi',
#   'would',
#   'say',
#   ':('],
#  ['know',
#   'song',
#   'disappear',
#   'phone',
#   'itun',
#   "i'v",
#   'lost',
#   'daze',
#   'confus',
#   ':('],
#  ['fever', ':-('],
#  ['think',
#   'surviv',
#   'well',
#   'find',
#   'miss',
#   'bodi',
#   'fragment',
#   "would'v",
#   'nice',
#   ':('],
#  ['@daretoattar', 'im', 'forc', 'go', ':-('],
#  ['horribl', 'weather', 'go', 'work', ':('],
#  ['@okayshesaid', 'wish', 'us', 'could', 'chang', ':('],
#  ['walao', 'kb', 'never', 'show', 'encor', ':('],
#  ['send', 'final', ':('],
#  ['ill', 'worst', ':('],
#  [':('],
#  ['hope',
#   '#djderek',
#   'found',
#   'safe',
#   'well',
#   'mani',
#   'fun',
#   'time',
#   'gig',
#   'absolut',
#   'legend',
#   ':('],
#  ['@qtbatooty_',
#   'yeah',
#   'like',
#   'need',
#   'wait',
#   'till',
#   'saturday',
#   'give',
#   'us',
#   'homework',
#   'pa',
#   ':(',
#   'u',
#   'made',
#   'plan',
#   '4',
#   'da',
#   'weekend'],
#  ['greek', 'tragedi', 'cute', 'song', ':('],
#  ['@bammyxoxo', '@stffnkthx', '@breeyanuh16', ':('],
#  ['rain', 'today', ':(', 'gym', '💪', '🏻', '🐒'],
#  ['@cutelilawley', 'what', 'wrong', ':('],
#  ['oh', 'god', "i'm", 'struck', 'pain', '...', 'cant', 'take', 'anymor', ':('],
#  ['@littlemix', 'come', 'belgium', ':('],
#  ['fabian', 'delph', 'fallen', ':(', '@bluearmy_ind', '@mcfc'],
#  ['@rosicky1987', 'u', 'hide', 'babi', ':('],
#  ["i'm", 'drake', 'silent', "can't", 'hear', ':('],
#  ['rest', 'peac', 'mo', ':('],
#  ['@mhsscho', 'much', 'chanc', 'game', 'tonight', ':(', '#t20blast'],
#  ['@ol_eyi', 'ahhh', 'u', 'see', 'u', 'wake', ':('],
#  ['mumma', 'im', '7', ':(', '@lmcdark_angel'],
#  ['@sarahhardman8', 'hope', ':('],
#  ["i'm", 'gonna', 'dead', 'tomorrow', ':('],
#  ['@_dedox', ':(', "i'll", 'high', 'low'],
#  ['@hanbin', 'sad', 'pray', ':('],
#  ['@britishsignbsl', 'appropri', ':('],
#  ['@redsordead', 'poor', '. . .', ':('],
#  ["i'm", 'still', 'awak', ':('],
#  ['woke', 'upp', 'cant', 'sleep', ':('],
#  ['one', 'help', ':('],
#  ['@curlsharryxoxo', 'know', ':(', 'happi', ':('],
#  ['@blvsamx', 'hi', 'dm', 'luke', 'pleas', ':('],
#  ['@kanchudarl',
#   '@vidyutjammw',
#   'hey',
#   'babe',
#   'came',
#   'across',
#   'pic',
#   '..',
#   'cant',
#   'read',
#   'hindi',
#   ':('],
#  ['reaction', ':('],
#  ['@junghoseok', '5s', ':(', 'think', 'bc', 'im', 'run', 'space', 'tbh'],
#  ['@rustyrocket',
#   'wish',
#   'could',
#   'come',
#   'see',
#   'disabl',
#   'pension',
#   'ptsd',
#   'make',
#   'imposs',
#   'physic',
#   'financi',
#   ':('],
#  ['rain', ':('],
#  ['@foooer_hungari',
#   '@foooersg',
#   'nooo',
#   'broke',
#   'soo',
#   'amaz',
#   'toghet',
#   ':('],
#  ['@mystikgunn',
#   'suck',
#   'mean',
#   'watch',
#   'play',
#   'around',
#   '1',
#   'p',
#   'time',
#   ':('],
#  ['like', ':(', 'https://t.co/gawf0bsr6a'],
#  ['@derekklahn', 'cant', 'hold', 'anoth', 'week', 'septemb', '21st', ':-('],
#  ['cut', 'encor', 'wanna', 'see', 'snsd', 'infinit', 'interact', ':('],
#  ['miss', 'watch', 'anna', 'akana', 'video', ':('],
#  ['@tokyato', 'askip', "t'exist", 'pa', ':('],
#  ['@9_moor',
#   'sadli',
#   ':(',
#   'channel',
#   'owner',
#   'decid',
#   'region',
#   'broadcast',
#   'thank',
#   'kei',
#   'pleas',
#   'rate',
#   'se',
#   '...',
#   'https://t.co/ezfehmtt5'],
#  ['dont',
#   'think',
#   '@camerondalla',
#   '@jackandjackr',
#   'ever',
#   'notic',
#   ':(',
#   'still',
#   'exist'],
#  ['traffic', 'terribl', ':('],
#  ['@joaannelopez',
#   "i'v",
#   'eye',
#   'small',
#   'kate',
#   'spade',
#   'bag',
#   'pero',
#   'walang',
#   'maganda',
#   ':('],
#  ['@mermaid_bl00d', 'haha', 'aw', 'miss', 'seen', 'agessss', ':('],
#  ['@energybieb', 'sigh', '...', ':('],
#  ['add',
#   'snapchat',
#   'corinehurleigh',
#   '#snapchat',
#   '#snapchatm',
#   '#instagram',
#   '#addmeonsnapchat',
#   '#sf',
#   '#quot',
#   '#kiksext',
#   ':(',
#   'http://t.co/8bk7ptaqar'],
#  ['bum', 'zara', 'trouser', ':('],
#  ['sushi', 'pic', 'tl', 'drive', 'craaaazzyy', ':('],
#  ['effect', 'spanish', ':('],
#  ['aww',
#   'poor',
#   'thing',
#   ':(',
#   'hope',
#   "it'okay",
#   'good',
#   'health',
#   'luck',
#   'freed',
#   'rock',
#   '#orcalov',
#   'https://t.co/toszmoafv6'],
#  ['@techverse_in', 'first', 'tri', 'http://t.co/xtszpi9fqw', 'result', ':('],
#  ['want', 'brace', 'back', ':('],
#  ['need', 'big', 'cuddl', 'lew', 'kiss', 'face', ':(', 'want', 'go'],
#  ['@xcrazy90skidx', '@kowtsnatinito', '@_patnicolexx', 'em', 'haha', ':('],
#  ['crave', 'banana', 'crumbl', 'mcflurri', 'fri', ':('],
#  ["we'r", 'go', 'cabl', 'car', 'brother', 'got', 'scare', 'want', ':('],
#  ['miss',
#   'hello',
#   "venus'",
#   'old',
#   'concept',
#   'tbh',
#   'rli',
#   'like',
#   'want',
#   'tea',
#   ':('],
#  ['tagal', ':('],
#  ["we'v",
#   'lost',
#   'album',
#   'broadcast',
#   'point',
#   ':(',
#   'http://t.co/qdsvs5q9sr'],
#  ['aw',
#   'appoint',
#   'tomorrow',
#   "i'd",
#   'like',
#   'feel',
#   'ok',
#   'go',
#   'sinc',
#   '>:('],
#  ['suck', 'want', 'go', 'home', ':('],
#  ["there'", 'milk', 'left', 'cereal', ':('],
#  ['@shahrukh9899', '@iammansoorkhan', 'huh', ':(', 'ye'],
#  ['lost', 'album', 'broadcast', ':('],
#  ['sad', ':(', 'http://t.co/fvv9y3wx2o', 'via', '@evoketoday'],
#  ['everyth', ':('],
#  ['@realliampayneph', 'follow', ':('],
#  ['@sainsburi',
#   'yeah',
#   'tri',
#   'film',
#   'date',
#   'start',
#   'time',
#   'film',
#   '4',
#   'day',
#   'left',
#   ':('],
#  ['@namwngr', 'get', 'one', 'think', 'previou', 'one', ':('],
#  ["can't", 'smile', ':('],
#  ["i'm", 'follow', '73', 'user', 'follow', 'back', ':('],
#  ['got', '7'],
#  ['@craigyboi', 'seem', 'everywher', 'today', ':('],
#  ['@oliviakaparang', '@bts_twt', 'fansign', 'take', 'photo', 'expens', ':('],
#  ['zzzzzz', '...', 'pleas', 'let', 'sun', 'come', 'yet', '...', ':('],
#  ["bff'", 'extrem', 'stress', "can't", 'anyth', 'pray', '...', ':('],
#  ['ahh', 'win', 'goodby', 'stage', ':('],
#  ['@st3cav',
#   '@mcfc',
#   '@sterling31',
#   '@yayatour',
#   'true',
#   "deosn't",
#   'help',
#   'liverpool',
#   'last',
#   'week',
#   'never',
#   'pool',
#   'though',
#   ':('],
#  ['@arunbuddyap', 'ye', 'bro', '..', 'lost', 'mani', ':('],
#  ['@jindaldaili', 'pray', 'sorri', 'happen'],
#  ['@jackshil',
#   'great',
#   'news',
#   'thank',
#   'let',
#   'us',
#   'know',
#   ':(',
#   'hope',
#   'good',
#   'weekend'],
#  ['@peachyiauren', 'fuck', ':('],
#  ['@locotaii', 'self', 'esteem', 'lowest', ':('],
#  ['@ryanbitchtit',
#   'feel',
#   'look',
#   'better',
#   'peopl',
#   "can't",
#   'see',
#   'tbh',
#   'look',
#   'tacki',
#   ':('],
#  ['@fabssulli', 'taken', 'say', ':('],
#  ['@asvpxgab', 'man', 'got', 'lucki', 'charm', ':('],
#  ['#haaretz',
#   '#israel',
#   ':-(',
#   'syria',
#   'continu',
#   'develop',
#   'chemic',
#   'weapon',
#   'offici',
#   'tell',
#   'wsj',
#   'wsj',
#   'rep',
#   '...',
#   'http://t.co/3c5prchkqw',
#   '#uniteblu',
#   '#tcot'],
#  ['want', 'bt', 'merch', ':('],
#  ['one', 'day', ':('],
#  ['taken', 'pic', 'mr', 'wong', 'confisc', 'art', 'work', ':('],
#  ['#bad4thwin', 'guy', 'omg', ':('],
#  ['@mustntgrumbl',
#   'thought',
#   'icepack',
#   'big',
#   'dose',
#   'pain',
#   'killer',
#   'board',
#   'feel',
#   'pain',
#   'alreadi',
#   ':(',
#   'whimper'],
#  ['okay', ':('],
#  ['@abeezygmt', 'say', 'man', 'u', 'fan', ':('],
#  ['@bibbyupd', ':(', 'wish', 'could', 'say', 'final', 'goodby'],
#  ['@_awkwardraven', 'senpai', '>:(', 'look', 'buttsex'],
#  ['@sabal_abla',
#   '@tanha_messiah',
#   'joke',
#   'headlin',
#   'friend',
#   ':(',
#   'pl',
#   "dn't",
#   'brk',
#   'heart',
#   ":'("],
#  ['someon',
#   'hit',
#   'head',
#   'voic',
#   "i'm",
#   'like',
#   'would',
#   'sound',
#   'amaz',
#   'could',
#   '...',
#   'falsetto',
#   ':('],
#  ['@patrickcf26', 'notic', ':('],
#  ['@versacelopez', 'hate', 'time', 'zone', ':('],
#  ['snapchat',
#   'leannerin',
#   '19',
#   '#snapchat',
#   '#hornykik',
#   '#loveofmylif',
#   '#dmme',
#   '#pussi',
#   '#newmus',
#   '#sexo',
#   ':(',
#   'http://t.co/tyhwg534ng'],
#  ['@dominionsyfi', 's2', 'air', 'spain', 'delay', 'kill', 'us', '...', ':('],
#  ['@theonion', '@chokyunghoon82', 'singl', 'untruth', ':('],
#  ['last',
#   'cross',
#   'countri',
#   'ij',
#   'amaz',
#   '💥',
#   '✨',
#   '💫',
#   "can't",
#   'bear',
#   'leav',
#   ':-(',
#   'https://t.co/vkvoxiaeqn'],
#  ['@_lizzy_kay', "can't", 'drive', ':('],
#  ['littl', 'apart', 'like', 'someon', 'come', 'live', ':-('],
#  ['soshi', 'didnt', 'win', ':(', 'buttt', 'congrat', 'infinit', '#bad4thwin'],
#  ['@rickygervai',
#   "i'm",
#   'work',
#   'saturday',
#   'sunday',
#   'friday',
#   'bad',
#   'day',
#   ':(',
#   ':('],
#  ['go', 'home', 'soon', ':('],
#  ['shoulda',
#   'move',
#   'away',
#   'w',
#   'boy',
#   'chanc',
#   'caus',
#   "they'r",
#   'peopl',
#   'want',
#   'time',
#   'like',
#   ':('],
#  ['heyyyyy', 'want', 'see', 'yeol', 'solo', 'danceeeee', ':('],
#  ['inter',
#   'offer',
#   'nemanja',
#   'vidic',
#   'roma',
#   '...',
#   'want',
#   'either',
#   ':(',
#   'http://t.co/ksdgy0ltpf',
#   'http://t.co/fplkjpxnqn'],
#  ["mom'",
#   'linguist',
#   "dad'",
#   'comput',
#   'scientist',
#   'dumbest',
#   'one',
#   'famili',
#   ':-('],
#  ['@gizmodouk',
#   'broken',
#   ':(',
#   'realli',
#   'want',
#   'morn',
#   'ice',
#   'cream',
#   'pour',
#   'rain',
#   '...',
#   'http://t.co/y9waxvqkpg'],
#  ['@hankgreen',
#   'would',
#   'ever',
#   'consid',
#   'creat',
#   'crash',
#   'cours',
#   'video',
#   'comput',
#   'scienc',
#   'mani',
#   'resourc',
#   'school',
#   ':('],
#  ['@uber', 'ice', 'cream', 'vehicl', 'busi', ':('],
#  ['ate',
#   'ayex',
#   'eat',
#   'your',
#   'sexi',
#   ':(',
#   '—',
#   'swear',
#   'eat',
#   'lot',
#   'chill',
#   'lamon',
#   'haha',
#   'http://t.co/cfoxw5wljz'],
#  ['weather',
#   'scroll',
#   'contact',
#   'peopl',
#   "i'v",
#   'curv',
#   'hey',
#   '😉',
#   'sigh',
#   ':('],
#  ["i'll", 'get', 'cement', 'cast', 'tomorrow', ':('],
#  ['shit', '10.3', 'k', ':('],
#  ['sign', ':(', 'https://t.co/y45q9gaj5j'],
#  ['@zaynmalik', 'zayn', ':('],
#  ['bot', 'follow', 'plz', 'send', 'mention', "can't", 'notic', ':('],
#  ['jmu', 'camp', 'teas', 'bc', 'wanna', ':('],
#  ['@mizznhe',
#   "that'",
#   'one',
#   'sweetest',
#   'thing',
#   "i'v",
#   'ever',
#   'said',
#   'awuna',
#   'mbulelo',
#   ':('],
#  ['fuck', 'bad', 'link', 'work', "can't", 'watch', 'match', ':('],
#  ['oh',
#   'mr',
#   'pig',
#   'turn',
#   ':(',
#   'although',
#   "there'",
#   'weird',
#   'crackl',
#   'nois',
#   'plug',
#   'come',
#   'plug',
#   "i'm",
#   'think',
#   'fuse'],
#  ['@titusoreili', 'dammit', 'tip', 'carlton', ':(', '#aflblueshawk'],
#  ['@baileymac02', 'miss', ':('],
#  ['@jiminist', 'go', 'bed', ':('],
#  ['want', 'go', "alex'", 'hous', ':('],
#  ['@motorsportcntrl',
#   '@gp2_offici',
#   'true',
#   'part',
#   'motorsport',
#   'seri',
#   'one',
#   'disc',
#   ':('],
#  ['want',
#   'right',
#   'follow',
#   'cheeki',
#   'j',
#   'instead',
#   "i'v",
#   'got',
#   'seo',
#   'nl',
#   'get',
#   ':('],
#  ['@boybandsftcara', 'sure', 'sorri', ':(', 'x'],
#  ['@talkingsimpson',
#   'hey',
#   'bud',
#   'christi',
#   'realli',
#   'sick',
#   "can't",
#   'leav',
#   '2',
#   'home',
#   ':(',
#   'xo',
#   'thank',
#   'man'],
#  ['niec', 'better', 'summer', ':('],
#  ['want', 'bloodi', 'sandwhich', ':('],
#  ['@whorgee', ':('],
#  ['buset', ':(', 'https://t.co/hq4y4fkniz'],
#  ['#discrimin',
#   ':-(',
#   'five',
#   'thing',
#   'learn',
#   'pregnanc',
#   'discrimin',
#   'today',
#   'left',
#   'foot',
#   'f',
#   '...',
#   'http://t.co/ey9mmasmsd',
#   '#uniteblu',
#   '#tcot'],
#  ['#discrimin',
#   ':-(',
#   'matern',
#   'discrimin',
#   'need',
#   'boss',
#   'kick',
#   'teeth',
#   '...',
#   'http://t.co/2wt4yymnwz',
#   '#uniteblu',
#   '#tcot'],
#  ['#domesticviol',
#   ':(',
#   'propos',
#   'new',
#   'law',
#   'help',
#   'domest',
#   'violenc',
#   'victim',
#   '98fm',
#   'victim',
#   '...',
#   'http://t.co/eoismrzlpo',
#   '#uniteblu',
#   '#vaw',
#   ':-('],
#  ['@nnoonlight', 'miss', ':(', 'okay', 'lol', 'noth', '😂'],
#  ['@hamzaabasiali', 'exactli', 'unfortun', ':('],
#  ['stress', 'upset', 'day', 'yesterday', 'uk', 'govern', 'suck', ':('],
#  ['ugh', 'well', 'could', 'still', 'say', "i'm", 'lucki', 'sapiosexu', ':('],
#  ['aww', 'bad', ':('],
#  ['ive', 'tri', 'play', 'damn', 'beta', 'like', '12', 'hour', ':('],
#  ['want', 'world', 'hulk', 'hogan', 'scrub', 'wwe', 'histori', ':-('],
#  ['im', 'tire', ':('],
#  ['weather', 'make', 'want', 'go', 'gym', '...', ':-('],
#  ['@katjturgoos', '@artsjob', 'link', 'work', ':('],
#  ['iren', 'seem', 'sad', 'make', 'mistak', ':('],
#  ['@itsssskelseyyyi', 'naa', 'unfortun', 'phone', ':('],
#  ['@bmthoffici', 'sold', ':('],
#  ['hate', 'u', '>:(', '#h_my_k'],
#  ['lose', ':('],
#  ['valentin',
#   'et',
#   'al',
#   'found',
#   "r'ship",
#   'btwn',
#   'homo',
#   'biphob',
#   'comment',
#   'certain',
#   'disciplin',
#   'incl',
#   'european',
#   'lang',
#   'lit',
#   'educ',
#   ':(',
#   '#fresherstofin'],
#  ['notic', ':(', "i'm", 'hopeless', '💔', '@seaveydaniel'],
#  ['dream',
#   'gettin',
#   'realist',
#   'like',
#   'thx',
#   'cant',
#   'tell',
#   'what',
#   'real',
#   'n',
#   'isnt',
#   ':('],
#  ['@sidebysid', 'either', 'would', 'prefer', 'benzema', 'get', 'though', ':('],
#  ['@dontvexmysoul',
#   'hahahahahaah',
#   'donno',
#   'korean',
#   'languag',
#   ':(',
#   'russian',
#   'waaaaa'],
#  ['@grofer', ':(', '#eidwithgrof'],
#  ['someon', 'talk', "i'm", 'boreddd', ':('],
#  ['hate', 'get', 'call', 'mug', 'piss', '>:('],
#  ['@mgapinoypatama', 'miss', 'know', '’', 'care', ':('],
#  ['@alexmcgraaa', "can't", 'option', 'phone', ':('],
#  ['@celestialsinn',
#   'love',
#   'tiddler',
#   'realli',
#   'silli',
#   ':(',
#   'least',
#   '’',
#   'get',
#   'real',
#   'new',
#   'card',
#   'like',
#   '1',
#   'hour',
#   '..'],
#  [':(', 'well', 'suck'],
#  ['infinit', 'win', ':('],
#  ['@sbs_mtv',
#   'sure',
#   'chorong',
#   'leader',
#   '#에이핑크',
#   '#더쇼',
#   "can't",
#   'sure',
#   'anymor',
#   ':('],
#  ['@clashwithcam', 'clan', 'slot', 'open', ':('],
#  ['pffff',
#   'privat',
#   '@bugcrowd',
#   '#bugbounti',
#   'find',
#   'self-xss',
#   'host',
#   'header',
#   'poison',
#   ':(',
#   'need',
#   'code',
#   'execut',
#   '#ktksbye'],
#  ['connect', 'leav', 'compani', 'alert', ':('],
#  ['@uberuk',
#   'cancel',
#   'ice',
#   'cream',
#   'uber',
#   'order',
#   'everyon',
#   'els',
#   'offic',
#   'got',
#   ':('],
#  ['@nebula2592',
#   'ahahah',
#   'consid',
#   'petit',
#   'love',
#   'hate',
#   'relationship',
#   'height',
#   ':('],
#  ['@therp_stefan',
#   '@therp_bv',
#   'cost',
#   '600',
#   'k',
#   '£',
#   'get',
#   'secur',
#   'alert',
#   'odoo',
#   '8',
#   'odoo',
#   'partner',
#   'far',
#   'commun',
#   'spirit',
#   ':-('],
#  ['jgh', ':(', 'im', 'effin', 'tire'],
#  ['facebook', 'u', 'work', 'u', 'facebook', ':('],
#  ['one', ':('],
#  ['@thenameisjas', 'unfortun', ':(', 'sorri'],
#  ['anyon', "else'", 'show', 'box', 'work', ':(', ':(', ':(', ':(', ':('],
#  ['ap', 'anymor', ':-('],
#  ['@llymlr',
#   'stori',
#   'life',
#   '...',
#   'love',
#   'london',
#   "can't",
#   'imagin',
#   'live',
#   'elsewher',
#   'gonna',
#   'happen',
#   'someday',
#   ':(',
#   'space'],
#  ['@benrwm',
#   'oh',
#   'ben',
#   ':-(',
#   'terribl',
#   'pleas',
#   'provid',
#   'us',
#   'name',
#   'branch',
#   'visit',
#   'would',
#   'like',
#   'address',
#   'concern'],
#  ['poor', 'guy', ':(', 'http://t.co/asq9nn4axr'],
#  ['@elninakaus', 'feel', 'pain', 'like', 'welsh', 'pod', ':('],
#  ['@buterasfredo', "can't", 'wait', 'movi', 'come', ':('],
#  ['@littlejules14',
#   'hi',
#   'juli',
#   "i'm",
#   'sorri',
#   'feel',
#   'way',
#   ':(',
#   'what',
#   'happen',
#   'laura'],
#  ['@maknaekooki',
#   'cant',
#   ':-(',
#   'im',
#   'still',
#   'insid',
#   'train',
#   'station',
#   'wait',
#   'person',
#   'home',
#   'anoth',
#   'hour',
#   'away',
#   'D;'],
#  ['@vegemitegri', 'anymor', ':('],
#  ['@wendykim',
#   '@joix05',
#   '@giladmillo',
#   'peopl',
#   'need',
#   'talk-kama',
#   'hawako',
#   'around',
#   ':(',
#   ':(',
#   'waa',
#   'kimaaaaaani',
#   'prisssss'],
#  ['baggag', 'claim', 'final', 'goodby', 'new', 'plane', 'friend', ':('],
#  ['miss', 'niamh', 'havent', 'seen', 'forev', ':('],
#  ['yeah', 'screw', ':-(', 'time', 'thought', 'someth', 'good', 'good'],
#  ['@lifeboatsupport', ':('],
#  ['@cherylwalmsley',
#   'hmmm',
#   'alway',
#   'much',
#   'sugar',
#   'rare',
#   'make',
#   'sorri',
#   'help',
#   ':('],
#  ['liter', 'time', 'watch', 'paper', 'town', ':('],
#  ['@donhutch4', "what'", 'score', "i'm", 'stuck', 'work', ':('],
#  ['agh', '@upcireland', 'keep', 'cut', 'middl', '#undercoverboss', ':-('],
#  ['@cmpunk',
#   '@mattjackson13',
#   'pleas',
#   'pleas',
#   'come',
#   'back',
#   'wwe',
#   ':(',
#   'تكفى'],
#  ['@cosplayamerica', "i'll", 'around', '10', 'train', 'delay', ':('],
#  ['full', 'time', 'job', 'mean', 'gonna', 'part', 'time', 'fun', ':('],
#  ['cat', 'forgotten', 'hate', ':('],
#  ['@vaxwel', 'know', 'long', 'play', '15', 'hour', ':('],
#  ['@newbreed_next', 'u', 'alreadi', ':('],
#  ['@kryaotic117', '@tritanarmyv2', '@moreconsol', 'yep', ':('],
#  ['must', 'video', 'stop', 'tho', ':('],
#  ['wisdom', 'teeth', 'give', 'much', 'ach', ':('],
#  ['one', ':-('],
#  ['wrist', 'feel', 'nake', 'bc', 'forgot', 'watch', 'bracelet', ':('],
#  ['@diamazi', 'ligo', 'na', ':('],
#  ['day',
#   'dozen',
#   'parent',
#   'children',
#   'kill',
#   'babi',
#   'shark',
#   'selfi',
#   ':(',
#   'https://t.co/s8cq6c91ni'],
#  ['heartach', ':('],
#  ['think', ':(', '#zayniscomingback'],
#  ['littl',
#   'mix',
#   'come',
#   'sweden',
#   'tomorrow',
#   "can't",
#   'see',
#   ':-(',
#   'im',
#   'sad'],
#  ['heart',
#   'breath',
#   'moment',
#   'time',
#   "i'll",
#   'find',
#   'word',
#   'say',
#   'leav',
#   'today',
#   ':('],
#  ['elmhurst', 'fc', ':-(', "i'll", 'alway', '#etid'],
#  ['miss', "chillin'with", ':(', '@princessreeev'],
#  ['forget', 'job', "i'm", 'sorri', 'father', ':('],
#  ['@scruffbucket',
#   'istanya',
#   'go',
#   '2suppli',
#   'extra',
#   'infrastructur',
#   'teacher',
#   'doctor',
#   'nurs',
#   'paramed',
#   'countless',
#   'thing',
#   '2cope',
#   '>:('],
#  ['like',
#   '@youtub',
#   'video',
#   'http://t.co/93z6wovos9',
#   'pasha',
#   'cri',
#   'terribl',
#   'donat',
#   ':('],
#  ["i'm", 'bore', 'plea', '1', 'arian', 'talk', ':('],
#  ['@hydrojeon', 'lmao', 'hahahaha', 'slr', 'jgh', 'school', ':('],
#  ['live', 'stream', 'suck', ':('],
#  ['kendal', 'kyli', 'kill', "kylie'", 'snapchat', ':('],
#  ['@maayangean',
#   'absolut',
#   'world',
#   'close',
#   'see',
#   'show',
#   'manila',
#   ':(',
#   'cri',
#   'fuck',
#   'hard',
#   'time'],
#  ['@jmcefala',
#   'jeebu',
#   'reabsorbt',
#   'tooth',
#   'abscess',
#   'threaten',
#   'affect',
#   'love',
#   'front',
#   'crown',
#   ':(',
#   'oooooooouch'],
#  ['oh', 'barney', ':('],
#  ['awh', ':(', 'nice', 'https://t.co/5zawc5z37j'],
#  ['sometim',
#   "be'",
#   'like',
#   'yo',
#   'follow',
#   'someon',
#   'day',
#   'later',
#   'realis',
#   "they'r",
#   'problemat',
#   'fuck',
#   'life',
#   ':('],
#  ['didnt', 'expect', 'omg', 'face', ':(', 'im', 'proud', 'infinit'],
#  ['day', 'mess', ':('],
#  ['miss', 'maa', ':(', 'ever', 'tell', 'go', 'like', 'without'],
#  ['help', ':('],
#  ['@thehindutheatr', '@evam_entd', 'bangalor', ':('],
#  ['@notredbutblu',
#   'awww',
#   ':(',
#   'least',
#   'u',
#   'never',
#   'got',
#   'call',
#   'lui',
#   'manzano',
#   'tho'],
#  ['@bebeshaaa', 'thank', 'shaaaa', 'miss', 'u', 'super', ':('],
#  ['get', '7th', 'win', ':('],
#  ['meet', 'conven', '2:30', 'pm', ':(', 'look', 'forward'],
#  ['@tweetseamu',
#   'parti',
#   'last',
#   'night',
#   'shame',
#   'go',
#   ':(',
#   'would',
#   'love',
#   'seen',
#   'x'],
#  ['@synergyfli', 'delet', ':('],
#  ['#turkey',
#   '#bomb',
#   '#isi',
#   '#syria',
#   'allow',
#   '#usa',
#   'use',
#   'one',
#   '#airfield',
#   '#jet',
#   ':('],
#  ['want',
#   "jack'",
#   'follow',
#   'bad',
#   'want',
#   'annoy',
#   'spam',
#   ':(',
#   'sooo',
#   '@jackgilinski',
#   'follow',
#   'pleas',
#   '☺',
#   '💜'],
#  ["mommy'", 'manila', "i'v", 'seen', ':('],
#  ['reason',
#   "i'm",
#   'alway',
#   'alway',
#   'overweight',
#   '...',
#   'sigeg',
#   'habhab',
#   ':(',
#   'masud',
#   'pa',
#   'kaha',
#   'ko',
#   'akong',
#   'un',
#   '…',
#   'http://t.co/rz52eutzmd',
#   'http://t.co/nvx057pfzp'],
#  ['@samayanyan',
#   'ye',
#   'thank',
#   'u',
#   'oh',
#   'damn',
#   'hella',
#   'suck',
#   ':-(',
#   'least',
#   'u',
#   'realli',
#   'good',
#   'time',
#   "that'",
#   'matter'],
#  ['@mollehgarcia', 'pala', 'omg', 'hahaha', 'drive', 'lesson', ':('],
#  ['aw',
#   'wanna',
#   'go',
#   'see',
#   'dolphin',
#   ':(',
#   'cute',
#   'xxx',
#   'http://t.co/rjbaffsmbh'],
#  ['@brighteyedmgc',
#   'holi',
#   'fuck',
#   'u',
#   'okay',
#   'text',
#   'u',
#   'need',
#   'anythin',
#   ':-('],
#  ['@xband__loverx', 'miss', ':('],
#  ['#zayniscomingbackonjuly26',
#   'see',
#   'trend',
#   'radio',
#   'next',
#   'sing',
#   'see',
#   '...',
#   ':('],
#  ['bewar',
#   'agonis',
#   'thought',
#   'experi',
#   'ahead',
#   ':(',
#   'https://t.co/b8ttz1wbkg'],
#  ['last',
#   'time',
#   'funer',
#   'funer',
#   'modimo',
#   'ho',
#   'tseba',
#   'wena',
#   'fela',
#   ':(',
#   '—',
#   'feel',
#   'emot',
#   '...',
#   'http://t.co/mqysswdot7'],
#  ["what'", 'wrong', ':('],
#  ['@lh_jm88', ':(', 'hubbi', 'delight', 'return', 'home', 'lol'],
#  ['sad', 'girl', 'oh', 'win', ':('],
#  ['@burloutray4', 'want', 'someth', 'new', 'damn', 'bill', ':('],
#  ['@someboysjump',
#   '@apriloumay',
#   'nowt',
#   'wors',
#   'sad',
#   'look',
#   'willi',
#   ':('],
#  ['@tonynamli', 'sad', 'moment', 'gon', 'vomit', ':('],
#  ['famou', 'bowl', ':('],
#  ['cute', ':(', 'http://t.co/5grpttmx8k'],
#  ['devast',
#   'find',
#   'last',
#   'night',
#   'titan',
#   'ae',
#   'never',
#   'actual',
#   'good',
#   ':-(',
#   'http://t.co/zzwd8hdcoi'],
#  ['@mark23baracael', 'mark', 'followback', ':('],
#  ['@latoyasilmon',
#   'omg',
#   '...',
#   'beauti',
#   '...',
#   'miss',
#   'soooooooo',
#   'much',
#   '...'],
#  ['@itstishh', 'miss', 'much', ':(', 'xxxxxx'],
#  ['use',
#   'nice',
#   'hair',
#   ':(',
#   'look',
#   'shini',
#   'long',
#   'wavi',
#   'im',
#   'emo',
#   'http://t.co/qx7xo8x5zq'],
#  ['@littlemix', 'fun', 'germani', ':(', "can't", '😭'],
#  ['make',
#   'tea',
#   'load',
#   'shed',
#   'like',
#   'ha',
#   'bheyp',
#   'ayemso',
#   'hack',
#   ':(',
#   'http://t.co/zudftknvcm'],
#  ['left', 'ear', 'swell', ':('],
#  ['read',
#   'sm',
#   'quot',
#   'fb',
#   'remind',
#   'abt',
#   'sm',
#   '1',
#   'miss',
#   'much',
#   ':('],
#  ['everyon', 'go', 'womad', ':('],
#  ['wut', 'hell', "can't", 'sleep', '>:('],
#  ['@corcor84', 'viciou', 'circl', ':(', 'x'],
#  ['@eydiespi', 'surpris', ':('],
#  ['win',
#   'ticket',
#   'codi',
#   'simpson',
#   'concert',
#   'singapor',
#   'august',
#   '10',
#   'http://t.co/6t9xkgtwtm',
#   '#spinorbinmusicxcodysimpson',
#   'pl',
#   'pl',
#   ':('],
#  ['@joyce_gleek', 'sorri', 'poooo', ':('],
#  ['sorri', 'na', 'bh3', ':(', '@alrakakir'],
#  ['project',
#   'want',
#   'enter',
#   '#pitchwar',
#   'may',
#   'work',
#   ':(',
#   'first',
#   'chap',
#   "mine'",
#   'phone',
#   'call',
#   'transcript',
#   '#ugh'],
#  ['@5sostumblrx', "apma'", ':('],
#  ['bad',
#   'shoulder',
#   'start',
#   'hurt',
#   'like',
#   'bitch',
#   ':(',
#   "we'r",
#   'day',
#   'away',
#   'competit',
#   'hope',
#   "it'll",
#   'fine',
#   'time'],
#  ['@shuaijerk', 'okay', 'feel', 'happen', 'timw', ':('],
#  ['@heyylawley', 'make', 'acc', 'feel', 'bad', ':(', "that'", 'rude'],
#  ['@meowkenzi',
#   ':(',
#   'suck',
#   'tri',
#   'vitamin',
#   'e',
#   'oil',
#   'massag',
#   'everyday',
#   'make',
#   'healthier',
#   'easier',
#   'stretch'],
#  ['hell',
#   'go',
#   'wrong',
#   ':(',
#   'understand',
#   'peopl',
#   'choos',
#   'hurt',
#   'https://t.co/hibjz4fc2r'],
#  ['know', "i'm", '#blockjam', 'sinc', "schedule'", 'whack', 'right', ':('],
#  ['@tymoss', 'wish', 'could', ':('],
#  ['guy',
#   'add',
#   'kik',
#   'thelock',
#   '76',
#   '#kik',
#   '#kiksext',
#   '#sex',
#   '#omegl',
#   '#coupl',
#   '#travel',
#   '#hotgirl',
#   ':(',
#   'http://t.co/dn6agzcphd'],
#  ['valentin',
#   'et',
#   'al',
#   '2009',
#   'found',
#   'relationship',
#   'homo',
#   'biphob',
#   'comment',
#   'certain',
#   'disciplin',
#   'incl',
#   'european',
#   'languag',
#   'lit',
#   'educ',
#   ':('],
#  ['3', 'ghantay', 'say', 'light', 'nai', 'hay', ':('],
#  ['@hereisjoshhil', 'still', 'work', ':('],
#  ['reject',
#   'reason',
#   'peopl',
#   'deni',
#   'realli',
#   'feel',
#   ':(',
#   '@maryjan71973628'],
#  ['weather', 'ruin', 'everyth', ':('],
#  ['@kryssen', 'laguna', ':('],
#  ['feel', 'sick', ':('],
#  [':(', 'exit', 'gomen'],
#  ['@sustinsanto',
#   'heck',
#   "that'",
#   'fair',
#   '😂',
#   'grew',
#   'half',
#   'inch',
#   'two',
#   'year',
#   ':('],
#  ['woke', 'feel', 'sick', ':('],
#  ['wish', 'cut', 'hair', 'like', ':(', 'http://t.co/oyt8wmo7w9'],
#  ['@nerfthorn', 'problem', '1', "i'm", 'uk', '£', '2', '25', ':('],
#  ['suuuuuuuper', 'sick', ':(', 'fever', 'got', 'way', 'wors', ':('],
#  ['right', ':(', 'http://t.co/hovzi9wqnx'],
#  ['65', 'digit', 'sale', '..', 'bad', 'feel', ':('],
#  ['use',
#   'anyon',
#   'netflix',
#   'account',
#   'inact',
#   'wanna',
#   'watch',
#   'orphan',
#   'black',
#   ':('],
#  ['havent', 'seen', 'earlier', ':('],
#  ['@fairyfunfwe', 'whaaat', ':('],
#  ['@margauxxemm', 'ye', 'babi', 'kaya', "i'm", 'sorri', ':('],
#  ['naaaaan', 'pa', 'goodby', 'stage', ':('],
#  ['@applemus', 'music', 'keep', 'paus', 'randomli', 'app', 'open', ':('],
#  ['3:30',
#   'walk',
#   'inglewood',
#   'ummm',
#   'bad',
#   'idea',
#   ':(',
#   'ugh',
#   'stupid',
#   'anxieti'],
#  ['easi', ':('],
#  ['@littlemix', 'belgium', ':('],
#  ['@randomdavemcc1',
#   'one',
#   'readi',
#   '3',
#   'week',
#   'also',
#   'charcoal',
#   'one',
#   'wont',
#   'readi',
#   'til',
#   'mid-end',
#   'aug',
#   ':-('],
#  ['noooo', '@pttbath', "i'v", 'heard', 'news', ':('],
#  ['@rodnerbroo', 'rip', 'rodfanta', ':-('],
#  ['wish', 'better', 'word', ':-('],
#  ['@wapaseeto', 'ye', 'wasp', 'sting', 'avert', 'bug', 'mean', ':('],
#  ['u', 'feel', ':(', '(:', '#exo', 'http://t.co/ghsa262orm'],
#  ['@zoellaftmend', 'pleas', 'leav', ':('],
#  ["i'm", 'feel', 'seekli', '...', ':('],
#  ['shock', 'news', ':(', '#riptito'],
#  ['@charalanahzard',
#   "can't",
#   'see',
#   "i'm",
#   'sorri',
#   'call',
#   'manbearpig',
#   'cannot',
#   'see',
#   'sorri',
#   ':('],
#  ['grow', 'shorter', 'pl', ':('],
#  ['@nimrodyel', 'academ', ':-('],
#  ['want', 'free', '@uberuk', 'ice', 'cream', ':-(', 'http://t.co/2bhfr9bu26'],
#  ['exclus',
#   'germani',
#   'unfair',
#   ':(',
#   'esp',
#   'regard',
#   'current',
#   'bleak',
#   'german',
#   'chart',
#   'situat',
#   'still',
#   'entri',
#   'even',
#   'top',
#   '100',
#   'pfft'],
#  ['@kwangqiiii', 'later', 'feel', 'place', ':('],
#  ['@borapl', 'white', 'wash', 'dude', 'polaroid', 'effect', ':-('],
#  ['feel', 'bad', 'talk', '...', ':('],
#  ['#newbethvideo',
#   'love',
#   'sooo',
#   'much',
#   '...',
#   'live',
#   'greec',
#   'dont',
#   'think',
#   "i'm",
#   'gonna',
#   'win',
#   ':(',
#   'alway',
#   'hope',
#   '<3'],
#  ['@courtneypink07',
#   'haha',
#   'know',
#   'right',
#   ':(',
#   'need',
#   'good',
#   'talk',
#   'xur'],
#  ['@gorobaoelisha', 'imi', ':('],
#  ['@emmalaalaaa',
#   'even',
#   'know',
#   "what'",
#   'go',
#   ':(',
#   'fill',
#   'pleas',
#   '#soon',
#   'babe',
#   '...',
#   '♡',
#   '♥',
#   '♡',
#   '♥',
#   'xoxoxo'],
#  ['@for1ros', 'rain', ':(', 'make', 'sure', 'get', 'pictur', 'soon'],
#  ['want', 'cereal', 'bad', '>:('],
#  ['got', 'home', 'lost', 'one', 'stud', 'ear', ':('],
#  ['miss', 'massag', ':('],
#  ['kik',
#   'guy',
#   'hund',
#   '6',
#   '#kik',
#   '#kikhorni',
#   '#tagsforlik',
#   '#skype',
#   '#kikchat',
#   '#amazon',
#   '#kikhorni',
#   ':(',
#   'http://t.co/jgb5w5ct7t'],
#  ['lost', '3.4', 'k', ':('],
#  ['yach',
#   '..',
#   'telat',
#   '..',
#   'huvvft',
#   '...',
#   ':(',
#   'https://t.co/nrzfh7roja'],
#  ['@junhuiass', 'year', 'sinc', 'zoo', 'fieldtrip', 'time', 'touch', ':('],
#  ['@attep', 'want', 'hug', 'watch', ':('],
#  ['@jackandjackr',
#   'miss',
#   'follow',
#   'spree',
#   ':(',
#   'next',
#   'time',
#   'though',
#   'x'],
#  ['still', 'hope', ':(', '#zayniscomingbackonjuly26'],
#  ['@edelabayog', 'awww', ':(', 'kaya', 'yan', 'think', 'posit'],
#  ['miss', 'king', 'futur', 'boss', 'rain', ':(', 'http://t.co/rztm0vkilm'],
#  ['want',
#   'watch',
#   'movi',
#   'listen',
#   'sizw',
#   'eat',
#   'write',
#   'assign',
#   'time',
#   '...',
#   "can't",
#   ':('],
#  ['@strawberrybon', 'miss', ':('],
#  ['time', '20', 'day', "i'll", 'result', 'km', ':('],
#  ['four', 'shift', 'left', '@taylorchurchman', 'heart', 'broken', ':('],
#  ['aaaaahhhhhhhh', ':(', '3', 'pm', 'feel', 'like', 'die', 'boredom', '...'],
#  ['@houseofpoiti', '@nurseneddi', '@peteski40', 'birthday', 'en', ':('],
#  ['stop',
#   'play',
#   'feel',
#   'man',
#   ':(',
#   'aint',
#   'got',
#   'time',
#   'still',
#   'hope',
#   '♡',
#   '#zayniscomingbackonjuly26',
#   'http://t.co/nu0pmygku9'],
#  ['@zedxgarcia', 'u', 'start', ':('],
#  ['one',
#   'who',
#   'dont',
#   'see',
#   'sins',
#   'trend',
#   'someth',
#   'like',
#   'that',
#   ':(',
#   '#zayniscomingbackonjuly26'],
#  ['good',
#   'thing',
#   'got',
#   'free',
#   'ear',
#   "i'v",
#   'somehow',
#   'lost',
#   'one',
#   'tini',
#   'screw',
#   'ball',
#   'thing',
#   'one',
#   'barbel',
#   ':('],
#  ['@jonnymale',
#   'owww',
#   "i'm",
#   'weekend',
#   "i'm",
#   'cours',
#   'next',
#   'week',
#   'abl',
#   'get',
#   'amsterdam',
#   ':('],
#  ['@rainymonday', 'luv', 'u', '💖', 'ps', 'talk', 'looooong', 'time', ':-('],
#  ['@gclliva', 'home', 'eye', 'aint', 'apart'],
#  ['@jackjcn', 'text', ':('],
#  ['@enikotsz', '@pooj_', '@uberuk', '@wall', 'rain', 'though', ':('],
#  ['@ollgbroxei', 'sc', 'long', ':('],
#  ['@ameamesakura', 'especi', 'like', ':(', "can't", 'song', ':/'],
#  ['cat', 'lap', 'go', ':(', 'http://t.co/wn3169k7kb'],
#  ['@ellierowexo', ':(', "i'm", 'litro', 'gonna', 'weekend'],
#  ['@giannepeq', 'shit', 'good', 'shepherd', 'lami', ':(', '3'],
#  ['@hawkerclaw', 'thank', 'mayb', 'late', 'sleep', ':('],
#  ['need',
#   'relax',
#   ':-(',
#   '...',
#   '#lungomar',
#   '#pesaro',
#   '#giachietittiwed',
#   '#igersoftheday',
#   '#summertim',
#   '#summer',
#   '…',
#   'https://t.co/ihfcehoxl3'],
#  ['nose', 'bruis', 'lil', ':(', ':('],
#  ['fuck',
#   'snake',
#   'thing',
#   'journey',
#   'alway',
#   'went',
#   'never',
#   'partner',
#   'beauti',
#   'scarf',
#   'ate',
#   ':('],
#  ['@jaredlovesjen',
#   "i'm",
#   'hope',
#   'come',
#   'back',
#   'au',
#   'afford',
#   'go',
#   'dont',
#   'think',
#   "i'll",
#   'abl',
#   ':('],
#  ['ruin',
#   '#fridayfeel',
#   'know',
#   'next',
#   'day',
#   'wake',
#   'earli',
#   'morn',
#   '...',
#   ':('],
#  ["i'll", 'sad', "there'", 'noth', 'tonight', ':('],
#  ['want', 'bad', 'bitch', 'aint', 'got', 'money', ':('],
#  ["can't", 'fri', 'chicken', 'woe', 'nigga', ':('],
#  ['#motn',
#   'though',
#   'light',
#   'make-up',
#   'justic',
#   ':(',
#   'http://t.co/nkza8s687n'],
#  ['one',
#   'person',
#   'still',
#   'import',
#   '...',
#   'want',
#   'gone',
#   'longer',
#   '...',
#   'yet',
#   'sit',
#   'scare',
#   'mind',
#   ':(',
#   '...'],
#  ['rli',
#   'wanna',
#   'buy',
#   'limit',
#   'ver',
#   'well',
#   'normal',
#   'edit',
#   'huhuhu',
#   'choos',
#   ':('],
#  ['@axolotl74', '@sp1305', 'stack', "m'ladi", 'j8', 'j11', 'm20', ':-('],
#  ['jk', 'im', 'bore', ':(', 'acad', 'schedul', '8', 'nowwww'],
#  ['@hamezr10', 'watch', 'cop', ':(', 'jame'],
#  ['need',
#   'clean',
#   'window',
#   'point',
#   'today',
#   'bc',
#   'hugh',
#   'keep',
#   'paw',
#   'leav',
#   'muddi',
#   'mark',
#   'everywher',
#   ':('],
#  ['know', 'song', 'sing', ':('],
#  ['@xcliffordpizza', 'mom', 'call', ':(', 'got', 'distract'],
#  ['@yseicedtey', 'heyi', 'miss', ':('],
#  ['pleas',
#   'nice',
#   'tomorrow',
#   'weather',
#   'otherwis',
#   'picnic',
#   'cancel',
#   "i'v",
#   'got',
#   '24',
#   'cupcak',
#   'eat',
#   ':-(',
#   'https://t.co/lgqrwfftio'],
#  ['@benzyyyyi', 'talaga', 'best', ':-(', '😂'],
#  ['femal', 'wanna', 'get', 'poppin', 'joc', '...', 'playin', ':('],
#  ['@taekookfev', 'cute', ':('],
#  ['@ninasarto', 'pm', ':('],
#  ['saw',
#   '#zayniscomingbackonjuly26',
#   'fix',
#   'coldplay',
#   'play',
#   'window',
#   'media',
#   'player',
#   ':(',
#   '😭',
#   'http://t.co/rgnnyzc31c'],
#  ['@_ferdelici',
#   'think',
#   'fail',
#   'one',
#   'subj',
#   ':-(',
#   'sobrang',
#   'bv',
#   '😭',
#   'pl',
#   'pray',
#   'huhu'],
#  ['zamn', 'line', 'afropunk', 'fest', 'brooklyn', ':('],
#  ['@lightmytorch',
#   "i'm",
#   'anymor',
#   'would',
#   'sign',
#   'saw',
#   ':(',
#   'thank',
#   'come'],
#  ['wish', 'id', 'put', '£', '50', 'real', 'madrid', '#shithous', ':('],
#  ['cutest', 'danc', 'ever', ':('],
#  ['@kimwoobin89__', 'oppa', '...', 'hug', 'ur', 'arm', 'like', ':('],
#  ['@jasonbarnard86',
#   '@stefgingerbal',
#   'ask',
#   'boss',
#   'rais',
#   'hand',
#   'ladder',
#   'told',
#   'climb',
#   'ladder',
#   'success',
#   ':-('],
#  ['@jenandmish', '@wittykrushn', 'get', 'get', ':('],
#  ['nerv', 'wrack', 'test', 'booset', ':('],
#  ['@mythor',
#   'aw',
#   'sad',
#   ':(',
#   'long',
#   'though',
#   'mayb',
#   'littl',
#   'longer',
#   'love',
#   'restart',
#   'assassin',
#   'creed',
#   'ii',
#   'heap',
#   'fell',
#   'love'],
#  ['@cragdoo',
#   'know',
#   'hell',
#   'play',
#   'next',
#   'one',
#   'find',
#   'way',
#   'turn',
#   ':('],
#  ['bore', ':('],
#  ["i'm", 'terribl', 'daughter', ':-('],
#  ['final',
#   'got',
#   'time',
#   'catch',
#   'game',
#   '..',
#   'wish',
#   'could',
#   'say',
#   'let',
#   'game',
#   'begin',
#   '...',
#   'sigh',
#   '..',
#   'ps3',
#   'work',
#   ':(',
#   'http://t.co/nwrirgsq8v'],
#  ['ankl', ':('],
#  ['step', 'puddl', ':-(', "i'm", 'wear', 'slipper'],
#  ['good', 'eve', ':('],
#  ['wake', 'bbi', 'imi', ':('],
#  ['cri', ':('],
#  ['video', 'sararoc', 'angri', 'world', ':(', 'http://t.co/egum20htok'],
#  ['pretti', 'hair', ':('],
#  ['fnaf', '4', 'come', 'holiday', ':('],
#  ['@1q4h_', 'cheer', ':-(', '😘', '💖'],
#  ['@thisisthebrook', 'mayb', 'tweet', ':('],
#  ['@annieappel', '@nutriculum', 'today', ':(', '#anywayhedidanicejob'],
#  ['@bethisbest01', '@styleswavi', '😞', ':('],
#  ['match', 'histori', ':('],
#  ['3am', "can't", 'sleep', ':('],
#  ['@jagexalfr', 'green', 'one', 'ugli', ':(', 'other', 'awesom', 'tho'],
#  ['local', 'legend', ':(', 'https://t.co/vvltlmosq0'],
#  ['@cruiselineuk',
#   '@azamaravoyag',
#   "can't",
#   'tell',
#   'sad',
#   'book',
#   'anoth',
#   'cruis',
#   'line',
#   'could',
#   'done',
#   'doubl',
#   'wail',
#   ':-('],
#  ['thing',
#   'go',
#   'wrong',
#   'go',
#   'wrong',
#   'broken',
#   'manual',
#   'wheelchair',
#   'check',
#   'get',
#   'one',
#   'fit',
#   'nh',
#   '26week',
#   'wait',
#   ':('],
#  ['poor',
#   'sbenu',
#   'sasin',
#   'happi',
#   '...',
#   'best',
#   'player',
#   'team',
#   '..',
#   ':(',
#   'anarchi',
#   '3',
#   '<3'],
#  ['@jenxmish', 'rude', 'af', 'im', 'gonna', 'put', 'candl', 'away', ':('],
#  ['@wydbayle',
#   'im',
#   'sure',
#   'anyon',
#   'would',
#   'kiss',
#   'ur',
#   'forehead',
#   'give',
#   'u',
#   'medicin',
#   'u',
#   'ask',
#   ':(',
#   'ur',
#   'welcom',
#   ':('],
#  ['@marsaliath', 'oop', ':('],
#  ['hoya', 'mah', 'alway', 'good', 'look', ':(', 'comment', 'a', ':('],
#  ['@jkottak', 'without', 'miss', ':('],
#  ['nobodi', 'said', 'easi', ':('],
#  ["i'm",
#   'sorri',
#   'give',
#   'enough',
#   'hug',
#   'awhil',
#   'ago',
#   'b',
#   'tire',
#   ':(',
#   'nice',
#   'see',
#   'luv',
#   '@nicoooootin'],
#  ['@jaxonoy', 'aw', 'miss', ':('],
#  ['@goodienuff',
#   'hush',
#   'gurli',
#   'bring',
#   'purti',
#   'mouth',
#   'closer',
#   'made',
#   'shiver',
#   ':('],
#  ['@mojangsupport',
#   'websit',
#   'solut',
#   'anyth',
#   'paid',
#   "can't",
#   'even',
#   'play',
#   'properli',
#   ':('],
#  ['dont', 'know', 'tri', 'anymor', 'get', 'tire', ':('],
#  ['@ryansugandi', 'gol', 'pea', ':('],
#  ['@spobabbbi', 'hate', 'know', 'english', ':('],
#  ['physic', 'emot', 'mental', '#tierd', ':('],
#  ['third', "eye'", 'get', 'activ', ':('],
#  ['@eggnigreg', 'thnkyouuuuuuuuu', ':('],
#  ['@simonshieldcar',
#   'hi',
#   'carolin',
#   ':(',
#   'neither',
#   '@motormistress',
#   '@glynhopkinshop',
#   'think',
#   'figur',
#   'us',
#   'lol'],
#  ['@hotsootaff', 'mirror', 'beauti', ':('],
#  ['@nuttyxand',
#   'make',
#   'highlight',
#   ':-(',
#   'seem',
#   'stop',
#   'talk',
#   'climb',
#   'pure',
#   'courag',
#   'bit',
#   'fishi'],
#  ['even', 'anyth', 'idek', ':('],
#  ['miss', 'apink', 'perform', ':('],
#  ['bulet', 'gendut', ':('],
#  ['#parti', 'goodby', 'stage', ':('],
#  ['@subharri', 'noo', ':(', 'know'],
#  ['@lollypng', ':(', 'hug', 'hope', 'rest', 'soon'],
#  ['@ovo4fev',
#   'look',
#   'awesom',
#   'miss',
#   'day',
#   'race',
#   'hotwheel',
#   'car',
#   'around',
#   'hous',
#   ':(',
#   'ms'],
#  ['patch', ':('],
#  ['@andytud', 'typic', 'power', 'cut', 'last', 'night', 'miss', ':(', 'good'],
#  ['@ellegow',
#   'ahaha',
#   "i'm",
#   'lay',
#   'bed',
#   'like',
#   'whyyyyyy',
#   'pretti',
#   'wine',
#   'glass',
#   'suck',
#   ':('],
#  ['@akon', '@tyres', "where'", 'album', 'akon', ':('],
#  ['@sulliyahh', 'sorri', 'didnt', 'updat', 'went', 'somewher', ':('],
#  ['never', 'end', 'nightmar', 'still', 'never', 'end', ':('],
#  ['@hugeboysmh', 'ya', 'ya', 'song', 'mino', ':('],
#  ['crazyyyy',
#   'thooo',
#   'zz',
#   'airport',
#   'straight',
#   'away',
#   'soundcheck',
#   'concert',
#   ':('],
#  ['@obscurro',
#   'hmm',
#   'tweet',
#   'antagonist',
#   'liter',
#   'sing',
#   'ob',
#   'song',
#   ':('],
#  ['phantasi',
#   'star',
#   'onlin',
#   '2',
#   'ip',
#   'issu',
#   'happi',
#   'could',
#   'final',
#   'play',
#   'game',
#   '...',
#   'sad',
#   ':(',
#   'http://t.co/du7z6cjyvm',
#   '@asiasoft_l'],
#  ['bruce', 'smile', ':(', 'http://t.co/uwldcqkcoq'],
#  ['2:30',
#   'morn',
#   '#sleepdepriv',
#   '#tiredashel',
#   '#looking4aspot',
#   'even',
#   "#kinara'",
#   'close',
#   '..',
#   ':(',
#   'chill',
#   '#awami',
#   'http://t.co/t47brjzsz5'],
#  ['cours',
#   ':(',
#   ':(',
#   '..',
#   'understand',
#   '@khalila_',
#   "y'all",
#   'gonna',
#   'ignor',
#   '@calvin_muca',
#   'question',
#   'huh',
#   'niqqa',
#   'desper',
#   'need',
#   'answer',
#   'lol'],
#  ['@sibulela_m', 'must', 'tini', ':('],
#  ['2', 'week', 'mockingjay', 'left', 'well', 'slow', ':('],
# ...
#   'aisyhhh',
#   'https://t.co/16poubmvlx'],
#  ['@clunis_96', 'eye', 'sinc', 'start', 'go', 'bald', 'age', '14', ':('],
#  ['seungchan', 'cant', 'get', ':(', 'aigooo', 'riri'],
#  ['@iainbruc', 'good', ':('],
#  ['origin', 'ticket', '£', '19', ':('],
#  ['@jakers787',
#   'depend',
#   'vet',
#   'visit',
#   'sick',
#   'cat',
#   ':(',
#   "i'll",
#   'let',
#   'know'],
#  ['@jenxmish', '@wittykrushn', 'leav', ':('],
#  ['wanna', 'get', ':('],
#  ['@elyusia',
#   'find',
#   'major',
#   'peopl',
#   'except',
#   'va',
#   "i'm",
#   'sure',
#   'kept',
#   'lumin',
#   'km',
#   '>:('],
#  ['@countrychoiceid', 'min', 'follback', ':('],
#  ['@martinamegia_', 'treat', 'horribl', 'ugh', ':(', 'im', 'v', 'happi', 'u'],
#  ['@kristikay13',
#   'good',
#   'morn',
#   'hope',
#   'product',
#   'one',
#   'time',
#   'get',
#   'readi',
#   'work',
#   ':('],
#  ['zayn', 'start', 'small', 'letter', 'z', ':(', '@real_liam_payn'],
#  ['@lifelesscurv',
#   "they'r",
#   'realli',
#   'uniqu',
#   'refresh',
#   ':(',
#   'popular',
#   'great',
#   '...'],
#  ['start', 'love', 'someon', '’', 'hard', 'stop', 'bebeeee', ':('],
#  ['chem', 'lt', 'nice', ':('],
#  ['@sabal_abla',
#   '@tanha_messiah',
#   'peopl',
#   'point',
#   'inaccuraci',
#   'joke',
#   'might',
#   'inaccur',
#   'joke',
#   'got',
#   'worri',
#   ':('],
#  ['@darkskinnedtoni', 'burn', 'rn', 'like', 'tragic', ':('],
#  ['woke', 'realli', 'hungri', ':('],
#  ['love', 'joy', ':('],
#  ['infinit', 'got', 'win', '>:('],
#  ['@planetrockradio',
#   'sam',
#   'seen',
#   'rush',
#   '19',
#   'time',
#   'would',
#   '20',
#   'toronto',
#   'flight',
#   'cancel',
#   'day',
#   'show',
#   ':(',
#   'stuart'],
#  ["party'", 'goodby', 'stage', ':('],
#  ['iyalaya',
#   'anybodi',
#   'would',
#   'laugh',
#   'today',
#   "i'd",
#   'wear',
#   'shade',
#   'round',
#   'clock',
#   ':('],
#  ['#zayniscomingbackonjuly26', ':(', ';('],
#  ['@godstalia', 'aw', 'fuck', 'suck', ':('],
#  ['@sianyw', 'happier', 'run', 'around', 'hous', 'wear', 'h', 'shirt', ':('],
#  ['@mars_sum41', 'noooo', ':(', 'goodby', 'fun', 'drive'],
#  ["i'm", 'bore', ':(', 'one', 'ubusi', 'le', 'fifa'],
#  ['@lorrainepalileo',
#   '@cailaaah',
#   'wanna',
#   'go',
#   'gymnast',
#   'guy',
#   ':(',
#   'haha'],
#  ["i'm", 'sick', 'aahhhh', 'hate', 'feel', ':-('],
#  ['ok', 'back', 'work', ':(', 'http://t.co/qftlz2cl0w'],
#  ['poor',
#   'noggin',
#   'bump',
#   'day',
#   'ago',
#   'still',
#   'hurt',
#   'littl',
#   ':(',
#   '#feelslikeanidiot'],
#  ["i'm", 'forev', 'eat', 'like', 'pregnant', 'woman', 'day', ':-('],
#  ['ugh', ':(', 'head', 'hurt'],
#  ['dearli', 'miss', 'love', 'sunshin', '@zaynmalik', ':-('],
#  ['@patelpatelxx',
#   '@starbuck',
#   'suk',
#   'buttttttt',
#   'except',
#   'pumpkin',
#   'scone',
#   '...',
#   'havent',
#   'made',
#   'year',
#   ':('],
#  ['love', 'outnumb', 'much', 'wish', 'watch', ':('],
#  ['vidcon', ':('],
#  ['@erislovesmovi', ':(', 'feel', 'better', 'soon', 'eri', '#support'],
#  ['hello',
#   '3',
#   'geez',
#   '..',
#   'badli',
#   'miss',
#   '12',
#   'preciou',
#   'star',
#   ':(',
#   'exo',
#   '<3'],
#  ['@beyfan1981',
#   '@hatethesefool',
#   'ye',
#   'hive',
#   'alway',
#   'suck',
#   'vote',
#   '...',
#   'shit',
#   ':('],
#  ['said',
#   '#got7',
#   'back',
#   '#vietnam',
#   'decemb',
#   'dunt',
#   'think',
#   'awwwwwwww',
#   ':(',
#   'kid'],
#  ['@marmaisxcz', 'ikr', ':(', 'lol'],
#  ['hear', 'sob', ':(', 'http://t.co/daoz0uaqgc'],
#  ['cute', ':(', 'http://t.co/hhhwqq1nh3'],
#  ['@sociopathslut', '@onikashabibi', 'buff', 'leg', 'yet', ':('],
#  ['noo', 'toni', 'deactiv', ':('],
#  ['bra', "shady'", 'kiss', 'though', ':-(', '#isibaya'],
#  ['place',
#   'forev',
#   'hold',
#   'special',
#   'place',
#   'heart',
#   ':-(',
#   '❤',
#   '️',
#   'gonna',
#   'miss',
#   'germani',
#   '😓',
#   'http://t.co/fwdwyovepv'],
#  ['realli',
#   'slept',
#   'night',
#   ':(',
#   "i'm",
#   'differ',
#   'place',
#   'littl',
#   'colder',
#   'hope',
#   'help',
#   'took',
#   'med'],
#  ['leav', 'airport', 'soon', ':(', 'wanna', 'go', 'home'],
#  ['@clemencycox', 'want', 'sausag', 'roll', ':-('],
#  ['rain', 'rain', 'go', 'away', ':('],
#  ['work', 'adio', 'friend', ':('],
#  ['cold', 'sore', ':(', 'ew', 'h8', 'help'],
#  ["what'", 'wrong', 'fb', 'messeng', ':('],
#  ['wish', 'band', 'shittier', 'could', 'get', 'book', 'leno', ':('],
#  ['ident', 'crisi', ':('],
#  ['3:33', 'roommat', 'offici', 'knock', ':(', 'much', 'nighter'],
#  ['bird', 'flew', 'window', 'dead', ':-('],
#  ['@damnkathleen', 'come', 'thru', 'b', 'miss', ':('],
#  ['@xxjenniferamyxx',
#   'derek',
#   'like',
#   'tour',
#   'visit',
#   'wetherspoon',
#   'pub',
#   'across',
#   'uk',
#   'get',
#   'polic',
#   'contact',
#   'h',
#   'hope',
#   'ok',
#   ':('],
#  ['@littlemix', 'pleas', 'follow', ':('],
#  ['even',
#   'dream',
#   'frank',
#   'ocean',
#   'releas',
#   'new',
#   'album',
#   'ff',
#   'pl',
#   ':('],
#  ['snapchat',
#   'lisah',
#   '19',
#   '#snapchat',
#   '#kikm',
#   '#kikmeboy',
#   '#woman',
#   '#eboni',
#   '#weloveyounamjoon',
#   '#sexi',
#   ':(',
#   'http://t.co/zvtysy29uk'],
#  ['know',
#   'gave',
#   'white',
#   'dress',
#   'small',
#   'polka',
#   'dot',
#   'away',
#   ':(',
#   '😭',
#   '😭',
#   'sigh',
#   'ndi',
#   'hack'],
#  ['miss', 'babi', ':-('],
#  ['@herfaith', "i'm", 'alreadi', 'bad', 'day', ':-('],
#  ['@erinare', 'yum', 'feed', '6', 'leftov', ':('],
#  ['@dullandwick',
#   '@_grahampatrick',
#   '@johnboystyl',
#   'nobodi',
#   'told',
#   'side',
#   'twitter',
#   'cs',
#   'own',
#   'sorri',
#   ':('],
#  ['last',
#   'dick',
#   'pic',
#   'got',
#   'aw',
#   'ruin',
#   'walnut',
#   'whip',
#   'life',
#   ':-(',
#   'also',
#   'name',
#   'turn',
#   'wife',
#   'follow'],
#  ['@vicioniu', 'boah', ':('],
#  ['thing', 'hard', 'right', "can't", 'even', 'home', 'madi', 'help', ':('],
#  [':('],
#  ['@epicrav', 'know', ':('],
#  ['@natalieh__xx',
#   'aww',
#   'last',
#   'semest',
#   'ever',
#   ':(',
#   'def',
#   'catch',
#   'sometim',
#   'soon',
#   'alway',
#   'leav',
#   'long'],
#  ['manga', 'cute', 'yet', 'made', 'cri', '..', ':(', 'http://t.co/kb6gswbxmt'],
#  ['@louisemensch', 'like', 'moment', '...', ':-('],
#  ['ate',
#   'leftov',
#   'giant',
#   '#aminormalyet',
#   'cooki',
#   'breakfast',
#   "i'm",
#   'clutch',
#   'poorli',
#   'tummi',
#   'pj',
#   'groan',
#   ':('],
#  ['@ghinesaddi', 'miss', ':('],
#  ['@_stroya',
#   'nou',
#   'your',
#   ':-(',
#   'pictur',
#   'adam',
#   'http://t.co/wevvpvoamx'],
#  ['@sinsalem', 'sad', 'moment', ':('],
#  ['@lukelegs69', 'right', ':('],
#  ['ken',
#   'sara',
#   'wait',
#   'sister',
#   'accid',
#   'poor',
#   ':(',
#   'https://t.co/44tvkavdcj'],
#  ['@rorington95',
#   'manag',
#   'sort',
#   'ticket',
#   'issu',
#   'mate',
#   'nobodi',
#   'pick',
#   'rang',
#   'box',
#   'offic',
#   ':('],
#  ['fk',
#   'freak',
#   'word',
#   'describ',
#   '...',
#   'eric',
#   'prydz',
#   'like',
#   ':(',
#   'world',
#   'http://t.co/w5udtzdhai'],
#  ['12',
#   'hour',
#   'sister-in-law',
#   'instal',
#   'new',
#   '@dionousa',
#   'seat',
#   'bought',
#   'rear-end',
#   "everyone'",
#   'fine',
#   'seat',
#   'trash',
#   ':('],
#  ['first',
#   'time',
#   'life',
#   "i'v",
#   'hold',
#   'boob',
#   'whilst',
#   'run',
#   'stair',
#   'bra',
#   'life',
#   ':('],
#  ['@ljenkins314', '@fringenerd', '@noin007', 'like', 'paper', 'book', ':('],
#  ['@sensodyneindia',
#   'friend',
#   'love',
#   'eat',
#   'ice',
#   'cream',
#   'childhood',
#   'miss',
#   'day',
#   ':(',
#   '#toothsensit'],
#  ['@father', ':-('],
#  ['@belinda_factor',
#   'stress',
#   ':(',
#   'even',
#   'dress',
#   'size',
#   'ke',
#   'shem',
#   '..'],
#  ['trust',
#   'well',
#   ':(',
#   'awel',
#   'long',
#   'drunk',
#   'care',
#   '#weekendofmad',
#   '🍹',
#   '🍸',
#   '🍹'],
#  ['realli', 'like', 'cb', 'outfit', 'time', 'bad', ':('],
#  ['@lucyreesxo', 'threaten', ':('],
#  ['wanna',
#   'dancer',
#   'wanna',
#   'choregraph',
#   'cant',
#   ':(',
#   'whyyyyyyyyyyyy',
#   'life',
#   'unfair'],
#  ['@kittykatpk', 'happen', 'anymor', ':('],
#  ['@curiouskittten',
#   'even',
#   'know',
#   'still',
#   'exist',
#   'haha',
#   'text',
#   ':(',
#   '626-430-8715'],
#  ['@subharri',
#   '@roguefond',
#   "i'v",
#   'messag',
#   'repli',
#   'dont',
#   'even',
#   'think',
#   'activ',
#   'facebook',
#   ':('],
#  ['@mlreu',
#   "i'm",
#   'work',
#   'hoe',
#   'xd',
#   "can't",
#   'even',
#   'look',
#   'bbi',
#   'peac',
#   ':('],
#  ['@suziepanol', 'us', ':('],
#  ['well', 'seem', 'like', 'dream', ':('],
#  ['dream', 'team', 'record', 'today', ':(', 'im', 'sad', 'xiu', 'make', ':('],
#  ['nk', 'gi', 'uss', 'birthday', ':('],
#  ['@hollieb', 'awwwwww', "i'm", 'sorri', 'hear', ':('],
#  ['@elissejoson',
#   'miss',
#   'much',
#   'ate',
#   'eliss',
#   ':(',
#   'u',
#   'still',
#   'rememb',
#   '😭'],
#  ['miss', 'much', ':('],
#  ['ksoo', 'make', 'emo', ':('],
#  ['wat',
#   'small',
#   'session',
#   'tat',
#   ':(',
#   '..',
#   'still',
#   'im',
#   'littl',
#   'happi',
#   'bcoz',
#   'first',
#   'time',
#   'heard',
#   'name',
#   '@rithvik_rd',
#   '..',
#   'still',
#   'short',
#   '..'],
#  ['@doomcrew_glen', 'awwwww', "i'm", 'sorri', ':(', 'bet', 'look', '<3', '3'],
#  ['matter', 'mani', 'time', 'tri', 'sleep', '...', "can't", ':('],
#  ['“', '@shakyra_cledera', 'paper', 'town', '”', 'sm', ':('],
#  ['@wittykrushn', 'go', ':('],
#  ["i'm",
#   'go',
#   'miss',
#   'babi',
#   ':(',
#   'rancho',
#   'imperi',
#   'de',
#   'silang',
#   'subdivis',
#   'https://t.co/b5jvtqpm4n'],
#  ['traffic', ':-('],
#  ['twitter',
#   'help',
#   'center',
#   '#39',
#   'follow',
#   'peopl',
#   'https://t.co/lel2yop3iq',
#   'via',
#   '@support',
#   'realli',
#   'realli',
#   'sorri',
#   'follow',
#   'evri',
#   'one',
#   ':('],
#  ['@franksredhotuk',
#   'hot',
#   'cornwal',
#   'verit',
#   'cold',
#   ':(',
#   'great',
#   'prize',
#   'xx'],
#  ['@hancoverdalexo', 'aww', ':(', 'thank', 'anyway'],
#  ['regular', 'gym', 'workout', 'bore', 'could', 'spin', ':('],
#  ["can't",
#   'anymor',
#   "can't",
#   'stress',
#   'bodi',
#   'yet',
#   'life',
#   'base',
#   'upon',
#   'stress',
#   "can't",
#   ':('],
#  ['@manofzinc',
#   'see',
#   'penni',
#   '...',
#   ':-(',
#   'dm',
#   'email',
#   'address',
#   "i'll",
#   'send',
#   'ebook'],
#  ['фотосет',
#   'addicted-to-analsex',
#   'sweetbj',
#   '#sweetbj',
#   '#blowjob',
#   'mhhh',
#   'want',
#   'make',
#   'man',
#   'happi',
#   ':(',
#   'http://t.co/v9rynd7pc'],
#  ['im',
#   'sed',
#   '..',
#   ':-(',
#   'person',
#   'im',
#   'meet',
#   'late',
#   'im',
#   'end',
#   'sg',
#   'havent',
#   'taken',
#   'dinner',
#   'yet',
#   'bless'],
#  ['@willing_h', 'feel', 'left', ':('],
#  ['@mblaq_seungh0',
#   'mention',
#   'mee',
#   'omg',
#   'enviou',
#   'pleas',
#   'oppa',
#   'eonni',
#   'stop',
#   'lovey',
#   'dovey',
#   'front',
#   'poor',
#   'singl',
#   'dongsaeng',
#   ':('],
#  ['@shannoneastwood',
#   "i'm",
#   'workin',
#   ':(',
#   'got',
#   'day',
#   'tuesday',
#   'tho',
#   'haha',
#   'x'],
#  ['@ulaaaaa1909', 'schade', ':('],
#  ['@cuddlesari', 'gut', 'never', 'g', 'belfast', ':('],
#  ['@klentmagsino',
#   'im',
#   'jealou',
#   '..',
#   ':(',
#   'follow',
#   'jacob',
#   '@jacobwhitesid',
#   '..',
#   'follow',
#   'jacob',
#   ':('],
#  ['isco', ':('],
#  ['@imrefleex', 'peni', 'small', ':('],
#  ['omg', 'everi', 'fuck', 'month', '...', ':(', 'https://t.co/fx0cgvpdmx'],
#  ['wish', 'dog', 'like', 'cuddl', ':('],
#  ['come', 'carlton', ':('],
#  ['@moonemojai',
#   'babe',
#   ':(',
#   'u',
#   'still',
#   'read',
#   'thru',
#   'convers',
#   'ur',
#   'hush'],
#  ['sometim',
#   'wonder',
#   'went',
#   'wrong',
#   ':(',
#   'guess',
#   "i'll",
#   'never',
#   'know'],
#  ['violenc',
#   '...',
#   ':(',
#   '...',
#   'soul',
#   'sick',
#   'nation',
#   '...',
#   'pray',
#   'louisiana',
#   '#lafayett',
#   '#matteroftheheart',
#   '#peac'],
#  ['waduh', '..', 'pant', ':(', 'https://t.co/aws63bitza'],
#  ['@keelzy81',
#   'know',
#   'actual',
#   'got',
#   'suspend',
#   'smoke',
#   'believ',
#   'teenag',
#   'fuck',
#   'clich',
#   ':('],
#  ['alreadi', 'miss', '@mikeyyfontt', 'much', ':('],
#  ['@bocassweet', 'miss', 'youuuu', ':('],
#  ['today', '#rma', 'jersey', ':('],
#  ['@butdinero', 'fake', 'text', ':('],
#  ['@earl_wolf24', ':('],
#  ['♥',
#   'eng',
#   '♥',
#   "let'",
#   'talk',
#   'sinc',
#   "can't",
#   'stream',
#   'game',
#   ':(',
#   'http://t.co/bknxszfjm6'],
#  ['@runemagiqu', 'chanc', ':('],
#  ['snapchat',
#   'jaclintil',
#   '#snapchat',
#   '#snapchat',
#   '#teen',
#   '#model',
#   '#likeforlik',
#   '#mpoint',
#   '#hotfmnoaidilforariana',
#   ':(',
#   'http://t.co/xxuygookcq'],
#  ['@superslothjai', 'hi', 'dm', 'luke', 'pleas', ':('],
#  ['@amandat_photo', '@oandthefox', 'realli', 'want', 'ran', 'time', ':('],
#  ['hate', 'wake', 'middl', 'sleep', ':('],
#  [':('],
#  ['@rupexo', '@lordofthem', 'fuckkk', 'wednesday', ':('],
#  ['@petitemistress',
#   'want',
#   'start',
#   'one',
#   'make',
#   'small',
#   'game',
#   'feel',
#   'like',
#   'need',
#   'get',
#   'jump',
#   'start',
#   'ask',
#   'support',
#   ':('],
#  ['justin', ':(', '@justinbieb'],
#  [':(', ':(', "i'm", 'gonna', 'cri'],
#  ['@ianhallard',
#   '@artstheatreldn',
#   "i'm",
#   'realli',
#   'excit',
#   'also',
#   'realli',
#   'sad',
#   'abl',
#   'see',
#   ':('],
#  ["can't", 'finish', 'sanum', 'today', ':(', '#llaollao', '#dessert', 'full'],
#  ['@jxstkati', '@thesvant', 'want', 'foood', ':('],
#  ['last', 'day', ':('],
#  ['#ubericecream', 'super', 'didnt', 'get', 'glare', ':(', '@uber_pun'],
#  ['@ffyeahh', 'know', 'vine', ':('],
#  ['@selenagomez',
#   'tweetin',
#   'earlier',
#   'morn',
#   ':(',
#   'sad',
#   'mood',
#   'day',
#   ':('],
#  ['sunggyu', 'plaster', 'elbow', '...', 'fall', ':-('],
#  ['@ughimnotsam', 'middl', 'figur', 'choreo', ':(', 'next', 'time', 'girl'],
#  ['@afooo93', '😭', 'think', 'well', 'offens', 'laugh', ':('],
#  ['@needtobreath', 'love', '..', 'sad', 'front', ':('],
#  ['yeyi',
#   'final',
#   'hd',
#   'brow',
#   'kit',
#   'broken',
#   'slightli',
#   ':(',
#   '@cohort',
#   'http://t.co/5cnhhfjpnj'],
#  ['@alexandraloise', 'monday', 'wednesday', 'g', 'na', 'girl', ':('],
#  ['babe', ':('],
#  ['miss', 'everyon', 'omg', ':(', 'school', 'sux', ':('],
#  ['@gelcababa', 'enjoy', ':('],
#  ['add',
#   'kik',
#   'nothaveld',
#   '765',
#   '#kik',
#   '#hornykik',
#   '#edm',
#   '#sexi',
#   '#likeforfollow',
#   '#hannib',
#   '#camsex',
#   ':(',
#   'http://t.co/ehtsuddrua'],
#  ['new', 'mosquito', 'bite', ':('],
#  ['@crmdk', 'kinki', 'shit', 'hsould', 'justget', 'marri', 'alreadi'],
#  ['realli', 'dont', 'wanna', 'go', 'home', 'today', ':('],
#  ['@idamelatim', 'la', ':('],
#  ['noth', 'like', 'us', 'come', 'shuffl', ':('],
#  ['@notch',
#   'hmm',
#   'think',
#   'get',
#   'one',
#   'might',
#   'get',
#   'one',
#   'int',
#   'futur',
#   'realli',
#   'miss',
#   'buckl',
#   'spring',
#   ':('],
#  ['ah',
#   'millz',
#   'aski',
#   ':(',
#   '@_millzxy3d',
#   'come',
#   'back',
#   'awusasho',
#   ":'(",
#   '@nessa_mbeki'],
#  ['@sainsburi',
#   'guy',
#   'realli',
#   'unlucki',
#   'one',
#   'driver',
#   'briefli',
#   'check',
#   'egg',
#   'half',
#   'spot',
#   'http://t.co/wpcqjhhbvk'],
#  ['tire', ':('],
#  ['im', 'great', 'still', 'see', 'u', 'despit', '144p', ':('],
#  ['@pikaiba',
#   'love',
#   'brook',
#   "i'm",
#   'concern',
#   'caus',
#   'face',
#   'crack',
#   ':('],
#  ['＠', 'maverickgam', 'juli', '24', '2015', '07:32', 'pm', ':('],
#  ['＠', 'maverickgam', 'juli', '24', '2015', '07:25', 'pm', ':('],
#  ['bore', 'max', 'rn', ':('],
#  ['@tudipa',
#   'sorri',
#   'manag',
#   'file',
#   'extern',
#   'sd',
#   'card',
#   'via',
#   'airdroid',
#   'support',
#   'android',
#   '4.4+',
#   ':(',
#   'googl',
#   'restrict'],
#  ['@fkluca', 'u', 'cute', 'thank', 'u', ':('],
#  ['@michaelc24h', 'alright', '...', 'cramp', 'kill', ':-('],
#  ['mayb', 'wrong', 'say', 'pleas', 'love', '3', ':('],
#  ['@blockedmefat', 'dont', 'unstan', 'tay', ':(', 'never', 'pleas'],
#  ['@sibulela_m',
#   'white',
#   'thing',
#   'ngeze',
#   'turn',
#   ':(',
#   'white',
#   'parti',
#   "i'v",
#   'noth',
#   'cocktaili',
#   'classi',
#   '😭',
#   '😭',
#   '😭',
#   'stress'],
#  ['@wbuharryy', 'love', ':('],
#  ['＠', 'maverickgam', 'juli', '24', '2015', '07:24', 'pm', ':('],
#  ['want', 'stuck', 'insid', 'day', ':('],
#  ['@cmonlukey', ':('],
#  ['@beardoftsu',
#   '@lucasweatherbi',
#   '@chrisjlatim',
#   '@alex_ams96',
#   'came',
#   'crash',
#   'hurt',
#   'insid',
#   ':('],
#  ['✈', '️2', 'day', "i'm", 'back', 'raini', 'uk', ':-(', '☔', '️'],
#  ['@peterpalmer52',
#   'hi',
#   'peter',
#   "we'v",
#   'pen',
#   '2',
#   'year',
#   "can't",
#   'get',
#   "there'",
#   'even',
#   'spare',
#   'offic',
#   'anymor',
#   'either',
#   ':('],
#  ['@biblioticaa', 'got', 'delay', 'guest', 'sigh', ':('],
#  ['@riseagainst',
#   'come',
#   'barcelona',
#   'year',
#   ':(',
#   'abl',
#   'see',
#   'madrid',
#   'bilbao',
#   '...'],
#  ['hate', 'japanes', 'call', 'bani', ':(', ':('],
#  ['wish', 'nice', 'booti', ':-('],
#  ['next',
#   'oh',
#   'yeah',
#   'sharyl',
#   'current',
#   'got',
#   '#shane',
#   'ta',
#   'call',
#   ':(',
#   'http://t.co/mozlqwvvq0'],
#  ['favourit', 'peopl', 'deactiv', ':('],
#  ['want', 'danc', 'rn', ':('],
#  ['im', 'still', 'giddi', 'd1', ':-('],
#  ['smile', 'beauti', ':(', 'https://t.co/oiahorqjob'],
#  ['@heidsbland',
#   '@asos95',
#   'ye',
#   '11',
#   'day',
#   'broken',
#   'zipper',
#   'broken',
#   'beyond',
#   'repair',
#   ':('],
#  ...]

# %%
#now we will build a frequency dict which tells us how many time a word appears in a positive
#and how many times in negetive

def build_freq(processed_tweets, val):
    '''
    returns a dict whose key is a tuple ('stemmed word',sentiment)
    '''
    freq={}
    for tweet in processed_tweets:
        for stem_word in tweet:
            pair = (stem_word,val)
            freq[pair]=freq.get(pair,0)+1
    return freq

# %%
word_freq={}
word_freq.update(build_freq(process_the_tweets(positve_tweets[:4000]),1))
word_freq.update(build_freq(process_the_tweets(negative_tweets[:4000]),0))

# %%
print(word_freq)
# Out:
# {('#followfriday', 1): 23, ('@france_int', 1): 1, ('@pkuchly57', 1): 1, ('@milipol_pari', 1): 1, ('top', 1): 30, ('engag', 1): 7, ('member', 1): 14, ('commun', 1): 26, ('week', 1): 72, (':)', 1): 2960, ('@lamb2ja', 1): 1, ('hey', 1): 60, ('jame', 1): 7, ('odd', 1): 2, (':/', 1): 5, ('pleas', 1): 81, ('call', 1): 27, ('contact', 1): 4, ('centr', 1): 1, ('02392441234', 1): 1, ('abl', 1): 6, ('assist', 1): 1, ('mani', 1): 28, ('thank', 1): 522, ('@despiteoffici', 1): 1, ('listen', 1): 15, ('last', 1): 39, ('night', 1): 55, ('bleed', 1): 2, ('amaz', 1): 41, ('track', 1): 5, ('scotland', 1): 2, ('@97side', 1): 1, ('congrat', 1): 15, ('yeaaaah', 1): 1, ('yippppi', 1): 1, ('accnt', 1): 2, ('verifi', 1): 2, ('rqst', 1): 1, ('succeed', 1): 1, ('got', 1): 57, ('blue', 1): 8, ('tick', 1): 1, ('mark', 1): 1, ('fb', 1): 4, ('profil', 1): 2, ('15', 1): 3, ('day', 1): 186, ('@bhaktisbant', 1): 16, ('@pallaviruhail', 1): 8, ('one', 1): 92, ('irresist', 1): 2, ('#flipkartfashionfriday', 1): 16, ('http://t.co/ebz0l2venm', 1): 1, ('like', 1): 187, ('keep', 1): 55, ('love', 1): 334, ('custom', 1): 4, ('wait', 1): 55, ('long', 1): 27, ('hope', 1): 115, ('enjoy', 1): 60, ('happi', 1): 157, ('friday', 1): 82, ('lwwf', 1): 1, ('https://t.co/smyyriipxi', 1): 1, ('@impatientraid', 1): 1, ('second', 1): 8, ('thought', 1): 21, ('’', 1): 17, ('enough', 1): 16, ('time', 1): 101, ('dd', 1): 1, ('new', 1): 114, ('short', 1): 6, ('enter', 1): 9, ('system', 1): 2, ('sheep', 1): 1, ('must', 1): 14, ('buy', 1): 10, ('jgh', 1): 3, ('go', 1): 123, ('bayan', 1): 1, (':D', 1): 523, ('bye', 1): 5, ('act', 1): 6, ('mischiev', 1): 1, ('etl', 1): 1, ('layer', 1): 1, ('in-hous', 1): 1, ('wareh', 1): 1, ('app', 1): 12, ('katamari', 1): 1, ('well', 1): 66, ('…', 1): 31, ('name', 1): 12, ('impli', 1): 1, (':p', 1): 104, ('@wncer1', 1): 1, ('@defense_gouv', 1): 1, ('influenc', 1): 16, ('big', 1): 28, ('...', 1): 228, ('juici', 1): 3, ('selfi', 1): 10, ('http://t.co/qvzjgd1ufo', 1): 1, ('http://t.co/owbl11eqri', 1): 1, ('@mish23615351', 1): 1, ('follow', 1): 382, ('@jnlazt', 1): 62, ('http://t.co/rcvcyyo0iq', 1): 62, ('u', 1): 204, ('back', 1): 139, ('@jjulieredburn', 1): 1, ('perfect', 1): 16, ('alreadi', 1): 19, ('know', 1): 128, ("what'", 1): 14, ('great', 1): 135, ('opportun', 1): 17, ('junior', 1): 2, ('triathlet', 1): 1, ('age', 1): 2, ('12', 1): 5, ('13', 1): 5, ('gatorad', 1): 1, ('seri', 1): 4, ('get', 1): 166, ('entri', 1): 3, ('http://t.co/of3dyozml0', 1): 1, ('lay', 1): 3, ('greet', 1): 4, ('card', 1): 6, ('rang', 1): 2, ('print', 1): 4, ('today', 1): 91, ('job', 1): 33, (':-)', 1): 552, ("friend'", 1): 3, ('lunch', 1): 3, ('yummmm', 1): 1, ('#nostalgia', 1): 1, ('#tb', 1): 1, ('#ku', 1): 1, ('@rookiesenpai', 1): 1, ('@arcadest', 1): 1, ('id', 1): 8, ('conflict', 1): 1, ('help', 1): 40, ("here'", 1): 20, ('screenshot', 1): 2, ('work', 1): 89, ('@oohdawg_', 1): 1, ('hi', 1): 154, ('liv', 1): 2, ('hello', 1): 48, ('need', 1): 62, ('someth', 1): 25, ('fm', 1): 2, ('twitter', 1): 25, ('—', 1): 22, ('sure', 1): 38, ('thing', 1): 48, ('dm', 1): 34, ('x', 1): 50, ('http://t.co/w6dy130bv7', 1): 1, ('@mbandscott_', 1): 1, ('@eric_fl', 1): 1, ('@pointsolutions3', 1): 1, ('@rossbreadmor', 1): 1, ("i'v", 1): 25, ('heard', 1): 9, ('four', 1): 5, ('season', 1): 5, ('pretti', 1): 16, ('dope', 1): 2, ('penthous', 1): 1, ('obv', 1): 1, ('#gobigorgohom', 1): 1, ('fun', 1): 44, ("y'all", 1): 4, ('@gculloty87', 1): 4, ('yeah', 1): 30, ('suppos', 1): 6, ('lol', 1): 47, ('chat', 1): 7, ('bit', 1): 16, ('youth', 1): 14, ('@tolajobjob', 1): 14, ('@maphisa301', 1): 1, ('💅', 1): 1, ('🏽', 1): 1, ('💋', 1): 2, ('seen', 1): 6, ('year', 1): 33, ('@bosslog', 1): 1, ('@amellywood', 1): 1, ('@cw_arrow', 1): 1, ('@arrowwrit', 1): 1, ('@johngutierrez1', 1): 1, ('rest', 1): 9, ('goe', 1): 4, ('quickli', 1): 3, ('bed', 1): 8, ('music', 1): 13, ('fix', 1): 6, ('dream', 1): 17, ('spiritu', 1): 1, ('ritual', 1): 1, ('festiv', 1): 7, ('népal', 1): 1, ('begin', 1): 4, ('line-up', 1): 4, ('left', 1): 10, (' ...

# %%
def word_count(words):
    '''
    return a list of tuples
    each tuple represents its appearce in positive and negetive tweets
    (word,pos_count,neg_count)
    '''
    lst = []
    for w in words:
        tple = (w,word_freq.get((w,1),0),word_freq.get((w,0),0))
        lst.append(tple)
    return lst

# %%
keys = ['happi', 'merri', 'nice', 'good', 'bad', 'sad', 'mad', 'best', 'pretti',
        '❤', ':)', ':(', '😒', '😬', '😄', '😍', '♛',
        'song', 'idea', 'power', 'play', 'magnific']
data= word_count(keys)
print(data)
# Out:
# [('happi', 157, 18), ('merri', 1, 0), ('nice', 71, 17), ('good', 191, 83), ('bad', 14, 50), ('sad', 5, 98), ('mad', 1, 8), ('best', 49, 16), ('pretti', 16, 12), ('❤', 21, 15), (':)', 2960, 2), (':(', 1, 3676), ('😒', 2, 3), ('😬', 0, 2), ('😄', 3, 1), ('😍', 1, 0), ('♛', 0, 210), ('song', 15, 25), ('idea', 24, 8), ('power', 6, 5), ('play', 37, 39), ('magnific', 0, 0)]

# %%
fig, ax = plt.subplots(figsize = (8,8))

# convert positive raw counts to logarithmic scale. we add 1 to avoid log(0)
x = np.log([x[1] + 1 for x in data])  

# do the same for the negative counts
y = np.log([x[2] + 1 for x in data]) 

# Plot a dot for each pair of words
ax.scatter(x, y)  
# assign axis labels
plt.xlabel("Log Positive count")
plt.ylabel("Log Negative count")

# Add the word as the label at the same position as you added the points just before
for i in range(0, len(data)):
    ax.annotate(data[i][0], (x[i], y[i]), fontsize=12)

    ax.plot([0, 9], [0, 9], color = 'red') # Plot the red line that divides the 2 areas.
plt.show()
# Out:
# /home/shaffat/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 128556 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/shaffat/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 128556 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
all_tweet = positve_tweets+negative_tweets

train =[]
train = process_the_tweets(positve_tweets[:4000]) +process_the_tweets(negative_tweets[:4000])

y_train = [1 for x in range(4000) ] + [0 for x in range(4000)]



test = []
test = process_the_tweets(positve_tweets[4000:])+process_the_tweets(negative_tweets[4000:])
y_test = [1 for x in range(1000) ] + [0 for x in range(1000)]


print(len(train))
print(len(test))
print(len(all_tweet))
print(len(y_train))
print(len(y_test))
print(train[0])
print(train[4000])
# Out:
# 8000
# 2000
# 10000
# 8000
# 2000
# ['#followfriday', '@france_int', '@pkuchly57', '@milipol_pari', 'top', 'engag', 'member', 'commun', 'week', ':)']
# ['hopeless', 'tmr', ':(']

# %%
#feature extraction
total = lambda sentence,x:sum(word_freq.get((word,x),0) for word in sentence)

for word in train[0]:
    print(word_freq.get((word,1),0),' ',word_freq.get((word,0),0),' ',word)
    
print(total(train[0],1))
print(total(train[0],0))

train_positive_point = [ total(sentence,1) for sentence in train]
train_negetive_point = [ total(sentence,0) for sentence in train]

test_positive_point = [ total(sentence,1) for sentence in test]
test_negetive_point = [ total(sentence,0) for sentence in test]
# Out:
# 23   0   #followfriday
# 1   0   @france_int
# 1   0   @pkuchly57
# 1   0   @milipol_pari
# 30   5   top
# 7   0   engag
# 14   6   member
# 26   1   commun
# 72   47   week
# 2960   2   :)
# 3135
# 61

# %%
X_train = pd.DataFrame(data={'pos':train_positive_point, 'neg':train_negetive_point})
X_test = pd.DataFrame(data={'pos':test_positive_point, 'neg':test_negetive_point})

# %%
X_train.head(20)
# Out:
#      pos  neg
# 0   3135   61
# 1   3706  444
# 2   3120  116
# 3   2976    4
# 4   3230  223
# 5   3095  120
# 6   4038  533
# 7   3281  278
# 8    655  189
# 9    265  114
# 10  3129   55
# 11  3793  715
# 12  4192  743
# 13  3193  206
# 14  3416  262
# 15  1029  240
# 16  3198  293
# 17  1207  249
# 18  3117   30
# 19  3647  540

# %%
X_test.head(20)
# Out:
#      pos  neg
# 0   3396  414
# 1   3410  397
# 2   1393  329
# 3   3280  401
# 4    791   27
# 5   3392  283
# 6    551   19
# 7   1143  430
# 8   1380  578
# 9   3199   29
# 10  3194  129
# 11  3147  253
# 12  3081   32
# 13  3049  104
# 14  2966    4
# 15  3482   96
# 16  3167  214
# 17   528    3
# 18   567   14
# 19   791   27

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr  = LogisticRegression(verbose=True, max_iter=1000)

# %%
lr.fit(X_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# LogisticRegression(max_iter=1000, verbose=True)

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_pred,y_test))
# Out:
# 0.994
